# %% [markdown]
# # HSE Продвинутые методы машинного обучения
#
# ## Семинар 9
#
# ### Полина Полунина
# polina.polunina@skolkovotech.ru
#
# # Стекинг, вотинг. Градиентный бустинг

# %% [markdown]
# Import packages:

# %%
#linear algebra
import numpy as np
#data structures
import pandas as pd
#ml models
import scipy as sp
import sklearn
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR
#plots
import matplotlib.pyplot as plt
# %matplotlib inline
#beautiful plots
import seaborn as sns
#linear regression
import statsmodels.api as sm
#set style for plots
sns.set_style('darkgrid')
#off the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Задание для Семинара номер 2:
#
#
# ## Часть 1: Для задачи регрессии:
#
# * подгрузите данные "train.csv"
# * поделите данные на тренировочную и тестовую выборки
# * обучите: линейную регрессию, svm, random forest
# * используйте предсказания от этих трех моделей для проверки качества ансамбля
# * используя предложенные техники ансамблей, проверьте, улучшился ли результат

# %% [markdown]
# ### Решение

# %% [markdown]
# *Подгружаем данные*

# %%
cols=['Id', 'MSSubClass', 'LotArea', 'OverallQual',\
      'OverallCond', 'YearBuilt', 'YearRemodAdd',\
      'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',\
     'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',\
     'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',\
     'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',\
     'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',\
     'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
data = pd.read_csv('train.csv', index_col=0, usecols=cols)
data.head()
# Out:
#     MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1           60     8450            7            5       2003          2003
# 2           20     9600            6            8       1976          1976
# 3           60    11250            7            5       2001          2002
# 4           70     9550            7            5       1915          1970
# 5           60    14260            8            5       2000          2000
#
#     BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  WoodDeckSF  OpenPorchSF  \
# Id                                              ...
# 1         150          856       856       854  ...           0           61
# 2         284         1262      1262         0  ...         298            0
# 3         434          920       920       866  ...           0           42
# 4         540          756       961       756  ...           0           35
# 5         490         1145      1145      1053  ...         192           84
#
#     EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# Id
# 1               0          0            0         0        0       2    2008
# 2               0          0            0         0        0       5    2007
# 3               0          0            0         0        0       9    2008
# 4             272          0            0         0        0       2    2006
# 5               0          0            0         0        0      12    2008
#
#     SalePrice
# Id
# 1      208500
# 2      181500
# 3      223500
# 4      140000
# 5      250000
#
# [5 rows x 31 columns]

# %% [markdown]
# *Делим данные на тренировочную и тестовую выборки*

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.drop('SalePrice', axis=1), data.SalePrice, test_size=0.2, random_state=32)

# %% [markdown]
# *Averaging*
#
# Алгоритм:
# * обучаем 3 модели на тренировочной выборке
# * делаем 3 предикта на тестовой выборке
# * усредняем
# * считаем целевую метрику $R^2$

# %%
# модель 1: линейная регрессия
from sklearn.linear_model import LinearRegression
# определяем и обучаем модель на тренировочной выборке
linreg = LinearRegression().fit(X_train, y_train)
# предсказываем на тестовой выборке
preds_linreg = linreg.predict(X_test)
# считаем скор на тестовой выборке
linreg.score(X_test, y_test)
# Out:
# 0.7638868743142141

# %%
# модель 2: random forest
from sklearn.ensemble import RandomForestRegressor
# определяем модель
rf = sklearn.ensemble.RandomForestRegressor()
# обучаем модель
model_rf = rf.fit(X_train, y_train)
# предсказываем
preds_rf = model_rf.predict(X_test)
# считаем скор
model_rf.score(X_test, y_test)
# Out:
# 0.7979846147381656

# %%
# модель 3: svm
from sklearn.svm import SVR
# определяем модель
svm = SVR(kernel='linear')
# обучаем модель
model_svm = svm.fit(X_train, y_train)
# предсказываем
preds_svm = model_svm.predict(X_test)
# считаем скор
model_svm.score(X_test, y_test)
# Out:
# 0.698663801279436

# %%
# усредняем три предсказания
averaged_preds = (preds_linreg + preds_rf + preds_svm) / 3

# %%
# считаем скор от усреднения
from sklearn.metrics import r2_score
r2_score(y_test, averaged_preds)
# Out:
# 0.7878624659897309

# %%
# считаем взвешенное среднее
averaged_weighted_preds = 0.2 * preds_linreg + 0.7 * preds_rf + 0.1 * predictions
# считаем скор
r2_score(y_test, averaged_weighted_preds)
# Out:
# 0.8057152212819878

# %% [markdown]
# *Stacking*
#
# Алгоритм:
# * обучаем 3 модели
# * делаем предсказания на тренировочной и тестовой выборках
# * добавляем предсказания от трех моделей в качестве новых признаков в X_train и X_test
# * обучаемся любой новой моделью на дополненном тренировочном сете
# * предсказываем на дополненной тестовой выборке
# * считаем скор

# %%
# предсказания на тренировочной выборке для трех моделей
# модель 1
preds_linreg_train = linreg.predict(X_train)
# модель 2
preds_rf_train = model_rf.predict(X_train)
# модель 3
preds_svm_train = model_svm.predict(X_train)

# %%
# добавляем предсказания в качестве новых признаков в тренировочную и тестовую выборки
X_train['linreg'] = preds_linreg_train
X_test['linreg'] = preds_linreg
X_train['rf'] = preds_rf_train
X_test['rf'] = preds_rf
X_train['svm'] = preds_svm_train
X_test['svm'] = preds_svm

# %%
# обучаем новую модель на дополненной тренировочной выборке
new_model_rf = rf.fit(X_train, y_train)
# считаем скор
new_model_rf.score(X_test, y_test)
# Out:
# 0.7742373629981207

# %% [markdown]
# *Blending*
#
# Алгоритм:
#  * делим тренировочный сет на две части
#  * обучаемся тремя моделями на первой части
#  * делаем предсказания для второй части и тестовой выборки
#  * добавляем предсказания для второй части и тестовой выборки в эту самую вторую часть и тестовую выборку
#  * обучаемся новой моделью на дополненной второй части
#  * делаем предсказания для дополненной тестовой выборки
#  * считаем скор

# %%
# убираем добавленные на этапе стекинга признаки
X_train = X_train.drop(['linreg', 'rf', 'svm'], axis=1)
X_test = X_test.drop(['linreg', 'rf', 'svm'], axis=1)

# %%
# делим тренировочный сет на две части
X_train_1, X_train_2, y_train_1, y_train_2 = train_test_split(X_train, y_train, test_size=0.4, random_state=32)

# %%
# обучаемся тремя моделями на первой части тренировочного сета
# модель 1
linreg = LinearRegression().fit(X_train_1, y_train_1)
preds_linreg_2 = linreg.predict(X_train_2)
preds_linreg_test = linreg.predict(X_test)
# скор на тесте
linreg.score(X_test, y_test)
# Out:
# 0.7549490198212486

# %%
# модель 2
rf = sklearn.ensemble.RandomForestRegressor()
model_rf = rf.fit(X_train_1, y_train_1)
preds_rf_2 = model_rf.predict(X_train_2)
preds_rf_test = model_rf.predict(X_test)
# считаем скор на тесте
model_rf.score(X_test, y_test)
# Out:
# 0.758292548420813

# %%
# модель 3
svm = SVR(kernel='linear')
model_svm = svm.fit(X_train_1, y_train_1)
preds_svm_2 = model_svm.predict(X_train_2)
preds_svm_test = model_svm.predict(X_test)
# считаем скор на тесте
model_svm.score(X_test, y_test)
# Out:
# 0.687485402687889

# %%
# добавляем признаки во вторую часть тренировочной и тестовую выборки
X_train_2['linreg'] = preds_linreg_2
X_test['linreg'] = preds_linreg_test
X_train_2['rf'] = preds_rf_2
X_test['rf'] = preds_rf_test
X_train_2['svm'] = preds_svm_2
X_test['svm'] = preds_svm_test

# %%
# обучаемся новой моделью на дополненной второй части тренировочной выборки
new_model_rf = rf.fit(X_train_2, y_train_2)
# считаем скор
new_model_rf.score(X_test, y_test)
# Out:
# 0.8160085251079233

# %% [markdown]
# *Bagging*
#
# Алгоритм:
# * делим тренировочный датасет на N частей с возвращением (бутстреппинг)
# * обучаем на каждой части разные модели и делаем предикт на тестовой выборке
# * финальное предсказание - усреднение всех предсказаний
# * считаем скор

# %%
# убираем из тестовой выборки добавленные при блендинге фичи
X_test = X_test.drop(['linreg', 'rf', 'svm'], axis=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# вспомогательный массив для предсказаний различных моделей
preds = []

# число моделей
n = 40
# кол-во строк в подвыборках
m = 300

# цикл для обучения моделей
for i in range(n):
    # подвыборка тренировочного сета: генерируем индексы строк случайным образом
    idx = np.random.choice(X_train.shape[0], m, replace=False)
    # подвыборка тренировочного сета: находим подвыборку
    X_sample = X_train.iloc[idx, :]
    y_sample = y_train.iloc[idx]
    # определяем модель, обучаем, делаем предсказания
    reg = DecisionTreeRegressor()
    model = reg.fit(X_sample, y_sample)
    predictions = model.predict(X_test)
    # сохраняем предсказания в наш вспомогательный массив
    preds.append(predictions)
    # выводим на экран индивидуальные скоры на тесте
    print('выборка {} | R2 на тесте: {:.2f}'.format(i+1, model.score(X_test, y_test)))
    
# финальное предсказание - усреднение всех предыдущих
final_preds = np.mean(preds, axis=0)
# считаем скор
print('\n\nфинальный скор на тесте: {:.2f}'.format(r2_score(y_test, final_preds)))
# Out:
# выборка 1 | R2 на тесте: 0.70
# выборка 2 | R2 на тесте: 0.70
# выборка 3 | R2 на тесте: 0.60
# выборка 4 | R2 на тесте: 0.65
# выборка 5 | R2 на тесте: 0.65
# выборка 6 | R2 на тесте: 0.57
# выборка 7 | R2 на тесте: 0.52
# выборка 8 | R2 на тесте: 0.62
# выборка 9 | R2 на тесте: 0.50
# выборка 10 | R2 на тесте: 0.67
# выборка 11 | R2 на тесте: 0.66
# выборка 12 | R2 на тесте: 0.65
# выборка 13 | R2 на тесте: 0.69
# выборка 14 | R2 на тесте: 0.63
# выборка 15 | R2 на тесте: 0.68
# выборка 16 | R2 на тесте: 0.67
# выборка 17 | R2 на тесте: 0.64
# выборка 18 | R2 на тесте: 0.67
# выборка 19 | R2 на тесте: 0.65
# выборка 20 | R2 на тесте: 0.65
# выборка 21 | R2 на тесте: 0.68
# выборка 22 | R2 на тесте: 0.68
# выборка 23 | R2 на тесте: 0.53
# выборка 24 | R2 на тесте: 0.58
# выборка 25 | R2 на тесте: 0.55
# выборка 26 | R2 на тесте: 0.50
# выборка 27 | R2 на тесте: 0.63
# выборка 28 | R2 на тесте: 0.59
# выборка 29 | R2 на тесте: 0.59
# выборка 30 | R2 на тесте: 0.62
# выборка 31 | R2 на тесте: 0.64
# выборка 32 | R2 на тесте: 0.64
# выборка 33 | R2 на тесте: 0.66
# выборка 34 | R2 на тесте: 0.66
# выборка 35 | R2 на тесте: 0.70
# выборка 36 | R2 на тесте: 0.58
# выборка 37 | R2 на тесте: 0.59
# выборка 38 | R2 на тесте: 0.55
# выборка 39 | R2 на тесте: 0.46
# выборка 40 | R2 на тесте: 0.64
#
#
# финальный скор на тесте: 0.80

# %% [markdown]
# ## Часть 2: Градиентный бустинг с пакетом catboost

# %% [markdown]
# На этом этапе мы будем использовать полный набор данных, но сначала уберем все признаки с большим кол-вом пропусков в данных, а затем уберем все оставшиеся строки с пропусками

# %%
# подгружаем полный набор данных
data = pd.read_csv('train.csv', index_col=0)
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
# 4        0      2    2006        WD        Abnorml     140000
# 5        0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
# удаляем признаки с кол-вом пропусков больше 200
mask = (data.isna().sum() <= 200)
cols = data.isna().sum()[mask].index.tolist()
data = data[cols]
# удаляем оставшиеся строки с пропусками 
data.dropna(inplace=True)
cat_features = data.dtypes[data.dtypes == 'object'].index.tolist()

# %% [markdown]
# Пакет catboost умеет работать с категориальными признаками, для этого сохраним названия столбцов с категориальными данными в отдельный массив

# %%
cat_features = data.dtypes[data.dtypes == 'object'].index.tolist()

# %% [markdown]
# Разделим данные на тренировочную, валидационную и тестовую выборки

# %%
# делим данные первый раз на тренировочную и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(data.drop('SalePrice', axis=1), data.SalePrice, test_size=0.2, random_state=32)
# делим тренировочный кусок на трейн и валидацию
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Импортируем catboost

# %%
from catboost import CatBoostRegressor, Pool

# %% [markdown]
# Используем Pool конструктор, чтобы создать тренировочный, валидационный и тестовый сеты. Передаем в соответствующую переменную имена категориальных столбцов.

# %%
train_data = Pool(X_train, y_train, cat_features=cat_features)
val_data = Pool(X_val, y_val, cat_features=cat_features)
test_data = Pool(X_test, y_test, cat_features=cat_features)

# %% [markdown]
# Прописываем желаемые параметры для алгоритма:
# * iterations - кол-во итераций
# * learning_rate - параметр, используется для варьирования шага градиента; чем значение ниже, тем медленнее сходится алгоритм
# * depth - глубина деревьев, оптимальные значения от 4 до 10
# * eval_metric - желаемая метрика для мониторинга качества модели
# * verbose - параметр, отвечающий за то, выводить ли результаты каждой итерации на экран
#
# Ссылка на описание всех возможных параметров для тюнинга модели: https://catboost.ai/docs/concepts/parameter-tuning.html
#
# Обратите внимание, что learning rate можно формально не прописывать, тогда он будет подобран автоматический в зависимости от кол-ва итераций

# %%
params={'iterations' : 500,
        'learning_rate' : 0.03,
        'eval_metric' : 'R2',
        'depth' : 5,
        'verbose' : True
        }

# %% [markdown]
# Далее все выглядит привычным нам образом

# %%
# определяем модель
model = CatBoostRegressor(**params)

# %%
# обучаем модель на тренировочных данных, при этом на каждой итерации мониторим результат на валидационной выборке
model.fit(train_data, eval_set=val_data)
# Out:
# 0:	learn: 0.0034681	test: 0.0041094	best: 0.0041094 (0)	total: 70.5ms	remaining: 35.2s
# 1:	learn: 0.0088492	test: 0.0091889	best: 0.0091889 (1)	total: 140ms	remaining: 34.8s
# 2:	learn: 0.0109156	test: 0.0124937	best: 0.0124937 (2)	total: 215ms	remaining: 35.7s
# 3:	learn: 0.0154288	test: 0.0177270	best: 0.0177270 (3)	total: 289ms	remaining: 35.8s
# 4:	learn: 0.0166346	test: 0.0190894	best: 0.0190894 (4)	total: 326ms	remaining: 32.3s
# 5:	learn: 0.0214098	test: 0.0234166	best: 0.0234166 (5)	total: 398ms	remaining: 32.7s
# 6:	learn: 0.0270514	test: 0.0291991	best: 0.0291991 (6)	total: 488ms	remaining: 34.3s
# 7:	learn: 0.0337481	test: 0.0352915	best: 0.0352915 (7)	total: 586ms	remaining: 36s
# 8:	learn: 0.0411919	test: 0.0419029	best: 0.0419029 (8)	total: 669ms	remaining: 36.5s
# 9:	learn: 0.0446383	test: 0.0450045	best: 0.0450045 (9)	total: 752ms	remaining: 36.9s
# 10:	learn: 0.0500254	test: 0.0505311	best: 0.0505311 (10)	total: 838ms	remaining: 37.2s
# 11:	learn: 0.0574758	test: 0.0583037	best: 0.0583037 (11)	total: 913ms	remaining: 37.1s
# 12:	learn: 0.0659740	test: 0.0670670	best: 0.0670670 (12)	total: 962ms	remaining: 36s
# 13:	learn: 0.0740805	test: 0.0750536	best: 0.0750536 (13)	total: 1.03s	remaining: 35.6s
# 14:	learn: 0.0830029	test: 0.0829946	best: 0.0829946 (14)	total: 1.15s	remaining: 37.1s
# 15:	learn: 0.0896926	test: 0.0895447	best: 0.0895447 (15)	total: 1.23s	remaining: 37.3s
# 16:	learn: 0.0961358	test: 0.0967454	best: 0.0967454 (16)	total: 1.32s	remaining: 37.5s
# 17:	learn: 0.1057150	test: 0.1060118	best: 0.1060118 (17)	total: 1.47s	remaining: 39.3s
# 18:	learn: 0.1144968	test: 0.1155060	best: 0.1155060 (18)	total: 1.62s	remaining: 41s
# 19:	learn: 0.1254205	test: 0.1267128	best: 0.1267128 (19)	total: 1.72s	remaining: 41.3s
# 20:	learn: 0.1360402	test: 0.1357722	best: 0.1357722 (20)	total: 1.83s	remaining: 41.7s
# 21:	learn: 0.1476090	test: 0.1473582	best: 0.1473582 (21)	total: 1.91s	remaining: 41.5s
# 22:	learn: 0.1561551	test: 0.1565482	best: 0.1565482 (22)	total: 2.02s	remaining: 42s
# 23:	learn: 0.1680539	test: 0.1680356	best: 0.1680356 (23)	total: 2.14s	remaining: 42.4s
# 24:	learn: 0.1781896	test: 0.1787840	best: 0.1787840 (24)	total: 2.24s	remaining: 42.5s
# 25:	learn: 0.1886144	test: 0.1888985	best: 0.1888985 (25)	total: 2.29s	remaining: 41.7s
# 26:	learn: 0.1961838	test: 0.1959048	best: 0.1959048 (26)	total: 2.36s	remaining: 41.4s
# 27:	learn: 0.2083874	test: 0.2067708	best: 0.2067708 (27)	total: 2.44s	remaining: 41.1s
# 28:	learn: 0.2221613	test: 0.2190125	best: 0.2190125 (28)	total: 2.52s	remaining: 41s
# 29:	learn: 0.2346247	test: 0.2301036	best: 0.2301036 (29)	total: 2.57s	remaining: 40.3s
# 30:	learn: 0.2474456	test: 0.2420386	best: 0.2420386 (30)	total: 2.64s	remaining: 40s
# 31:	learn: 0.2547235	test: 0.2484411	best: 0.2484411 (31)	total: 2.67s	remaining: 39.1s
# 32:	learn: 0.2679182	test: 0.2608392	best: 0.2608392 (32)	total: 2.74s	remaining: 38.8s
# 33:	learn: 0.2809531	test: 0.2724136	best: 0.2724136 (33)	total: 2.82s	remaining: 38.7s
# 34:	learn: 0.2949960	test: 0.2856691	best: 0.2856691 (34)	total: 2.89s	remaining: 38.4s
# 35:	learn: 0.3083382	test: 0.2990346	best: 0.2990346 (35)	total: 2.97s	remaining: 38.3s
# 36:	learn: 0.3223902	test: 0.3120064	best: 0.3120064 (36)	total: 3.04s	remaining: 38.1s
# 37:	learn: 0.3354402	test: 0.3239205	best: 0.3239205 (37)	total: 3.16s	remaining: 38.4s
# 38:	learn: 0.3484204	test: 0.3365146	best: 0.3365146 (38)	total: 3.28s	remaining: 38.7s
# 39:	learn: 0.3600518	test: 0.3474880	best: 0.3474880 (39)	total: 3.34s	remaining: 38.5s
# 40:	learn: 0.3726344	test: 0.3588104	best: 0.3588104 (40)	total: 3.39s	remaining: 37.9s
# 41:	learn: 0.3860348	test: 0.3701732	best: 0.3701732 (41)	total: 3.46s	remaining: 37.7s
# 42:	learn: 0.4006523	test: 0.3842814	best: 0.3842814 (42)	total: 3.57s	remaining: 38s
# 43:	learn: 0.4130850	test: 0.3949632	best: 0.3949632 (43)	total: 3.69s	remaining: 38.3s
# 44:	learn: 0.4260156	test: 0.4063790	best: 0.4063790 (44)	total: 3.8s	remaining: 38.4s
# 45:	learn: 0.4390756	test: 0.4176782	best: 0.4176782 (45)	total: 3.92s	remaining: 38.7s
# 46:	learn: 0.4506431	test: 0.4293500	best: 0.4293500 (46)	total: 4.03s	remaining: 38.9s
# 47:	learn: 0.4636052	test: 0.4408585	best: 0.4408585 (47)	total: 4.14s	remaining: 39s
# 48:	learn: 0.4745911	test: 0.4497231	best: 0.4497231 (48)	total: 4.24s	remaining: 39s
# 49:	learn: 0.4867859	test: 0.4605757	best: 0.4605757 (49)	total: 4.3s	remaining: 38.7s
# 50:	learn: 0.4991690	test: 0.4710167	best: 0.4710167 (50)	total: 4.34s	remaining: 38.3s
# 51:	learn: 0.5109866	test: 0.4820551	best: 0.4820551 (51)	total: 4.4s	remaining: 37.9s
# 52:	learn: 0.5220247	test: 0.4914200	best: 0.4914200 (52)	total: 4.49s	remaining: 37.8s
# 53:	learn: 0.5317237	test: 0.4989224	best: 0.4989224 (53)	total: 4.58s	remaining: 37.8s
# 54:	learn: 0.5420913	test: 0.5079613	best: 0.5079613 (54)	total: 4.62s	remaining: 37.4s
# 55:	learn: 0.5534402	test: 0.5163809	best: 0.5163809 (55)	total: 4.68s	remaining: 37.1s
# 56:	learn: 0.5631091	test: 0.5228988	best: 0.5228988 (56)	total: 4.79s	remaining: 37.2s
# 57:	learn: 0.5730764	test: 0.5318402	best: 0.5318402 (57)	total: 4.86s	remaining: 37.1s
# 58:	learn: 0.5831272	test: 0.5406728	best: 0.5406728 (58)	total: 4.94s	remaining: 37s
# 59:	learn: 0.5923327	test: 0.5486886	best: 0.5486886 (59)	total: 5.02s	remaining: 36.8s
# 60:	learn: 0.6019251	test: 0.5563508	best: 0.5563508 (60)	total: 5.1s	remaining: 36.7s
# 61:	learn: 0.6100790	test: 0.5624556	best: 0.5624556 (61)	total: 5.16s	remaining: 36.4s
# 62:	learn: 0.6200801	test: 0.5728625	best: 0.5728625 (62)	total: 5.26s	remaining: 36.5s
# 63:	learn: 0.6290517	test: 0.5815833	best: 0.5815833 (63)	total: 5.34s	remaining: 36.4s
# 64:	learn: 0.6367826	test: 0.5886742	best: 0.5886742 (64)	total: 5.39s	remaining: 36.1s
# 65:	learn: 0.6433995	test: 0.5954979	best: 0.5954979 (65)	total: 5.42s	remaining: 35.6s
# 66:	learn: 0.6503537	test: 0.6009938	best: 0.6009938 (66)	total: 5.5s	remaining: 35.5s
# 67:	learn: 0.6570733	test: 0.6051347	best: 0.6051347 (67)	total: 5.57s	remaining: 35.4s
# 68:	learn: 0.6659039	test: 0.6127212	best: 0.6127212 (68)	total: 5.67s	remaining: 35.4s
# 69:	learn: 0.6720250	test: 0.6184252	best: 0.6184252 (69)	total: 5.71s	remaining: 35.1s
# 70:	learn: 0.6793031	test: 0.6240797	best: 0.6240797 (70)	total: 5.76s	remaining: 34.8s
# 71:	learn: 0.6861366	test: 0.6296719	best: 0.6296719 (71)	total: 5.85s	remaining: 34.8s
# 72:	learn: 0.6922201	test: 0.6346513	best: 0.6346513 (72)	total: 5.93s	remaining: 34.7s
# 73:	learn: 0.6988001	test: 0.6404356	best: 0.6404356 (73)	total: 6.01s	remaining: 34.6s
# 74:	learn: 0.7040974	test: 0.6462177	best: 0.6462177 (74)	total: 6.1s	remaining: 34.6s
# 75:	learn: 0.7102903	test: 0.6530371	best: 0.6530371 (75)	total: 6.19s	remaining: 34.5s
# 76:	learn: 0.7164270	test: 0.6585205	best: 0.6585205 (76)	total: 6.27s	remaining: 34.4s
# 77:	learn: 0.7217217	test: 0.6626362	best: 0.6626362 (77)	total: 6.33s	remaining: 34.2s
# 78:	learn: 0.7267129	test: 0.6669381	best: 0.6669381 (78)	total: 6.41s	remaining: 34.2s
# 79:	learn: 0.7328023	test: 0.6718758	best: 0.6718758 (79)	total: 6.51s	remaining: 34.2s
# 80:	learn: 0.7376142	test: 0.6759718	best: 0.6759718 (80)	total: 6.62s	remaining: 34.2s
# 81:	learn: 0.7428792	test: 0.6803922	best: 0.6803922 (81)	total: 6.71s	remaining: 34.2s
# 82:	learn: 0.7465563	test: 0.6833413	best: 0.6833413 (82)	total: 6.78s	remaining: 34.1s
# 83:	learn: 0.7506303	test: 0.6871752	best: 0.6871752 (83)	total: 6.84s	remaining: 33.9s
# 84:	learn: 0.7555051	test: 0.6893986	best: 0.6893986 (84)	total: 6.91s	remaining: 33.8s
# 85:	learn: 0.7589776	test: 0.6922130	best: 0.6922130 (85)	total: 6.96s	remaining: 33.5s
# 86:	learn: 0.7625577	test: 0.6955761	best: 0.6955761 (86)	total: 6.99s	remaining: 33.2s
# 87:	learn: 0.7662047	test: 0.6988934	best: 0.6988934 (87)	total: 7.07s	remaining: 33.1s
# 88:	learn: 0.7701957	test: 0.7028135	best: 0.7028135 (88)	total: 7.16s	remaining: 33.1s
# 89:	learn: 0.7728418	test: 0.7050948	best: 0.7050948 (89)	total: 7.19s	remaining: 32.8s
# 90:	learn: 0.7763283	test: 0.7080567	best: 0.7080567 (90)	total: 7.26s	remaining: 32.6s
# 91:	learn: 0.7789596	test: 0.7098339	best: 0.7098339 (91)	total: 7.34s	remaining: 32.6s
# 92:	learn: 0.7812466	test: 0.7114583	best: 0.7114583 (92)	total: 7.38s	remaining: 32.3s
# 93:	learn: 0.7845765	test: 0.7151288	best: 0.7151288 (93)	total: 7.42s	remaining: 32s
# 94:	learn: 0.7865940	test: 0.7168996	best: 0.7168996 (94)	total: 7.44s	remaining: 31.7s
# 95:	learn: 0.7898901	test: 0.7201620	best: 0.7201620 (95)	total: 7.53s	remaining: 31.7s
# 96:	learn: 0.7927153	test: 0.7225165	best: 0.7225165 (96)	total: 7.65s	remaining: 31.8s
# 97:	learn: 0.7954766	test: 0.7246201	best: 0.7246201 (97)	total: 7.74s	remaining: 31.7s
# 98:	learn: 0.7983017	test: 0.7276938	best: 0.7276938 (98)	total: 7.8s	remaining: 31.6s
# 99:	learn: 0.8006621	test: 0.7298563	best: 0.7298563 (99)	total: 7.89s	remaining: 31.6s
# 100:	learn: 0.8025283	test: 0.7312756	best: 0.7312756 (100)	total: 7.96s	remaining: 31.4s
# 101:	learn: 0.8051539	test: 0.7341919	best: 0.7341919 (101)	total: 8.03s	remaining: 31.3s
# 102:	learn: 0.8069293	test: 0.7357171	best: 0.7357171 (102)	total: 8.08s	remaining: 31.1s
# 103:	learn: 0.8094840	test: 0.7373863	best: 0.7373863 (103)	total: 8.14s	remaining: 31s
# 104:	learn: 0.8120701	test: 0.7400989	best: 0.7400989 (104)	total: 8.22s	remaining: 30.9s
# 105:	learn: 0.8137785	test: 0.7411533	best: 0.7411533 (105)	total: 8.3s	remaining: 30.9s
# 106:	learn: 0.8156466	test: 0.7428482	best: 0.7428482 (106)	total: 8.36s	remaining: 30.7s
# 107:	learn: 0.8168828	test: 0.7438913	best: 0.7438913 (107)	total: 8.43s	remaining: 30.6s
# 108:	learn: 0.8185152	test: 0.7459071	best: 0.7459071 (108)	total: 8.49s	remaining: 30.5s
# 109:	learn: 0.8198332	test: 0.7472811	best: 0.7472811 (109)	total: 8.54s	remaining: 30.3s
# 110:	learn: 0.8216111	test: 0.7488118	best: 0.7488118 (110)	total: 8.63s	remaining: 30.2s
# 111:	learn: 0.8240051	test: 0.7511404	best: 0.7511404 (111)	total: 8.74s	remaining: 30.3s
# 112:	learn: 0.8263976	test: 0.7514088	best: 0.7514088 (112)	total: 8.85s	remaining: 30.3s
# 113:	learn: 0.8274460	test: 0.7523338	best: 0.7523338 (113)	total: 8.91s	remaining: 30.2s
# 114:	learn: 0.8294849	test: 0.7550629	best: 0.7550629 (114)	total: 8.99s	remaining: 30.1s
# 115:	learn: 0.8311961	test: 0.7564781	best: 0.7564781 (115)	total: 9.11s	remaining: 30.2s
# 116:	learn: 0.8330025	test: 0.7575556	best: 0.7575556 (116)	total: 9.22s	remaining: 30.2s
# 117:	learn: 0.8347724	test: 0.7588758	best: 0.7588758 (117)	total: 9.32s	remaining: 30.2s
# 118:	learn: 0.8362008	test: 0.7597673	best: 0.7597673 (118)	total: 9.41s	remaining: 30.1s
# 119:	learn: 0.8377013	test: 0.7610643	best: 0.7610643 (119)	total: 9.48s	remaining: 30s
# 120:	learn: 0.8387010	test: 0.7612430	best: 0.7612430 (120)	total: 9.59s	remaining: 30s
# 121:	learn: 0.8402329	test: 0.7622884	best: 0.7622884 (121)	total: 9.7s	remaining: 30s
# 122:	learn: 0.8413075	test: 0.7631111	best: 0.7631111 (122)	total: 9.79s	remaining: 30s
# 123:	learn: 0.8424065	test: 0.7641017	best: 0.7641017 (123)	total: 9.86s	remaining: 29.9s
# 124:	learn: 0.8435553	test: 0.7651607	best: 0.7651607 (124)	total: 9.95s	remaining: 29.9s
# 125:	learn: 0.8450458	test: 0.7655454	best: 0.7655454 (125)	total: 10.1s	remaining: 29.9s
# 126:	learn: 0.8458998	test: 0.7661439	best: 0.7661439 (126)	total: 10.1s	remaining: 29.7s
# 127:	learn: 0.8475000	test: 0.7663509	best: 0.7663509 (127)	total: 10.2s	remaining: 29.7s
# 128:	learn: 0.8486872	test: 0.7665180	best: 0.7665180 (128)	total: 10.3s	remaining: 29.7s
# 129:	learn: 0.8493306	test: 0.7671238	best: 0.7671238 (129)	total: 10.4s	remaining: 29.6s
# 130:	learn: 0.8504948	test: 0.7676685	best: 0.7676685 (130)	total: 10.5s	remaining: 29.6s
# 131:	learn: 0.8514988	test: 0.7688616	best: 0.7688616 (131)	total: 10.6s	remaining: 29.6s
# 132:	learn: 0.8528737	test: 0.7691584	best: 0.7691584 (132)	total: 10.7s	remaining: 29.6s
# 133:	learn: 0.8536837	test: 0.7691951	best: 0.7691951 (133)	total: 10.8s	remaining: 29.5s
# 134:	learn: 0.8544345	test: 0.7695924	best: 0.7695924 (134)	total: 10.9s	remaining: 29.4s
# 135:	learn: 0.8549332	test: 0.7697579	best: 0.7697579 (135)	total: 11s	remaining: 29.3s
# 136:	learn: 0.8561139	test: 0.7695771	best: 0.7697579 (135)	total: 11.1s	remaining: 29.4s
# 137:	learn: 0.8571011	test: 0.7716824	best: 0.7716824 (137)	total: 11.2s	remaining: 29.3s
# 138:	learn: 0.8580640	test: 0.7721679	best: 0.7721679 (138)	total: 11.2s	remaining: 29.2s
# 139:	learn: 0.8591033	test: 0.7728948	best: 0.7728948 (139)	total: 11.3s	remaining: 29.1s
# 140:	learn: 0.8604596	test: 0.7741580	best: 0.7741580 (140)	total: 11.4s	remaining: 29s
# 141:	learn: 0.8609917	test: 0.7743424	best: 0.7743424 (141)	total: 11.5s	remaining: 28.9s
# 142:	learn: 0.8614438	test: 0.7741094	best: 0.7743424 (141)	total: 11.5s	remaining: 28.7s
# 143:	learn: 0.8617556	test: 0.7743847	best: 0.7743847 (143)	total: 11.5s	remaining: 28.5s
# 144:	learn: 0.8626330	test: 0.7749107	best: 0.7749107 (144)	total: 11.6s	remaining: 28.3s
# 145:	learn: 0.8635529	test: 0.7756568	best: 0.7756568 (145)	total: 11.7s	remaining: 28.3s
# 146:	learn: 0.8645712	test: 0.7765236	best: 0.7765236 (146)	total: 11.8s	remaining: 28.3s
# 147:	learn: 0.8655861	test: 0.7766842	best: 0.7766842 (147)	total: 11.9s	remaining: 28.2s
# 148:	learn: 0.8661588	test: 0.7772896	best: 0.7772896 (148)	total: 11.9s	remaining: 28.1s
# 149:	learn: 0.8666934	test: 0.7779699	best: 0.7779699 (149)	total: 12s	remaining: 27.9s
# 150:	learn: 0.8672576	test: 0.7778218	best: 0.7779699 (149)	total: 12.1s	remaining: 27.9s
# 151:	learn: 0.8676636	test: 0.7781278	best: 0.7781278 (151)	total: 12.2s	remaining: 27.9s
# 152:	learn: 0.8683788	test: 0.7779901	best: 0.7781278 (151)	total: 12.3s	remaining: 27.9s
# 153:	learn: 0.8690368	test: 0.7780179	best: 0.7781278 (151)	total: 12.4s	remaining: 27.8s
# 154:	learn: 0.8698460	test: 0.7781991	best: 0.7781991 (154)	total: 12.5s	remaining: 27.8s
# 155:	learn: 0.8705130	test: 0.7786673	best: 0.7786673 (155)	total: 12.6s	remaining: 27.7s
# 156:	learn: 0.8710655	test: 0.7793929	best: 0.7793929 (156)	total: 12.7s	remaining: 27.7s
# 157:	learn: 0.8722653	test: 0.7794889	best: 0.7794889 (157)	total: 12.8s	remaining: 27.6s
# 158:	learn: 0.8728387	test: 0.7799716	best: 0.7799716 (158)	total: 12.8s	remaining: 27.5s
# 159:	learn: 0.8732945	test: 0.7806459	best: 0.7806459 (159)	total: 12.9s	remaining: 27.5s
# 160:	learn: 0.8735664	test: 0.7810441	best: 0.7810441 (160)	total: 13s	remaining: 27.3s
# 161:	learn: 0.8738507	test: 0.7812155	best: 0.7812155 (161)	total: 13s	remaining: 27.1s
# 162:	learn: 0.8743886	test: 0.7818311	best: 0.7818311 (162)	total: 13s	remaining: 27s
# 163:	learn: 0.8748248	test: 0.7820973	best: 0.7820973 (163)	total: 13.1s	remaining: 26.9s
# 164:	learn: 0.8753411	test: 0.7823912	best: 0.7823912 (164)	total: 13.2s	remaining: 26.9s
# 165:	learn: 0.8757538	test: 0.7826115	best: 0.7826115 (165)	total: 13.3s	remaining: 26.8s
# 166:	learn: 0.8761318	test: 0.7832136	best: 0.7832136 (166)	total: 13.4s	remaining: 26.7s
# 167:	learn: 0.8764852	test: 0.7831049	best: 0.7832136 (166)	total: 13.5s	remaining: 26.6s
# 168:	learn: 0.8768035	test: 0.7831847	best: 0.7832136 (166)	total: 13.6s	remaining: 26.6s
# 169:	learn: 0.8771290	test: 0.7833843	best: 0.7833843 (169)	total: 13.7s	remaining: 26.5s
# 170:	learn: 0.8773405	test: 0.7831133	best: 0.7833843 (169)	total: 13.7s	remaining: 26.4s
# 171:	learn: 0.8780406	test: 0.7835871	best: 0.7835871 (171)	total: 13.8s	remaining: 26.4s
# 172:	learn: 0.8784299	test: 0.7852039	best: 0.7852039 (172)	total: 13.9s	remaining: 26.3s
# 173:	learn: 0.8787980	test: 0.7855022	best: 0.7855022 (173)	total: 14s	remaining: 26.2s
# 174:	learn: 0.8791534	test: 0.7857393	best: 0.7857393 (174)	total: 14.1s	remaining: 26.1s
# 175:	learn: 0.8794747	test: 0.7865337	best: 0.7865337 (175)	total: 14.2s	remaining: 26.1s
# 176:	learn: 0.8803672	test: 0.7867233	best: 0.7867233 (176)	total: 14.3s	remaining: 26s
# 177:	learn: 0.8809116	test: 0.7864327	best: 0.7867233 (176)	total: 14.3s	remaining: 26s
# 178:	learn: 0.8812708	test: 0.7860073	best: 0.7867233 (176)	total: 14.4s	remaining: 25.8s
# 179:	learn: 0.8817583	test: 0.7866000	best: 0.7867233 (176)	total: 14.5s	remaining: 25.8s
# 180:	learn: 0.8821768	test: 0.7866940	best: 0.7867233 (176)	total: 14.6s	remaining: 25.7s
# 181:	learn: 0.8824856	test: 0.7869910	best: 0.7869910 (181)	total: 14.7s	remaining: 25.7s
# 182:	learn: 0.8828196	test: 0.7872566	best: 0.7872566 (182)	total: 14.8s	remaining: 25.6s
# 183:	learn: 0.8832926	test: 0.7877060	best: 0.7877060 (183)	total: 14.8s	remaining: 25.5s
# 184:	learn: 0.8837682	test: 0.7882354	best: 0.7882354 (184)	total: 14.9s	remaining: 25.4s
# 185:	learn: 0.8843161	test: 0.7884512	best: 0.7884512 (185)	total: 15s	remaining: 25.4s
# 186:	learn: 0.8845928	test: 0.7884729	best: 0.7884729 (186)	total: 15.1s	remaining: 25.3s
# 187:	learn: 0.8849047	test: 0.7886407	best: 0.7886407 (187)	total: 15.2s	remaining: 25.2s
# 188:	learn: 0.8849264	test: 0.7886241	best: 0.7886407 (187)	total: 15.2s	remaining: 25s
# 189:	learn: 0.8853567	test: 0.7889177	best: 0.7889177 (189)	total: 15.3s	remaining: 24.9s
# 190:	learn: 0.8855402	test: 0.7892584	best: 0.7892584 (190)	total: 15.3s	remaining: 24.8s
# 191:	learn: 0.8856125	test: 0.7893258	best: 0.7893258 (191)	total: 15.3s	remaining: 24.6s
# 192:	learn: 0.8861691	test: 0.7890619	best: 0.7893258 (191)	total: 15.4s	remaining: 24.5s
# 193:	learn: 0.8866220	test: 0.7892890	best: 0.7893258 (191)	total: 15.5s	remaining: 24.5s
# 194:	learn: 0.8868599	test: 0.7895230	best: 0.7895230 (194)	total: 15.6s	remaining: 24.5s
# 195:	learn: 0.8870914	test: 0.7891038	best: 0.7895230 (194)	total: 15.7s	remaining: 24.4s
# 196:	learn: 0.8871620	test: 0.7891560	best: 0.7895230 (194)	total: 15.8s	remaining: 24.3s
# 197:	learn: 0.8875422	test: 0.7892564	best: 0.7895230 (194)	total: 15.9s	remaining: 24.2s
# 198:	learn: 0.8881757	test: 0.7895279	best: 0.7895279 (198)	total: 16s	remaining: 24.2s
# 199:	learn: 0.8885956	test: 0.7896373	best: 0.7896373 (199)	total: 16.1s	remaining: 24.1s
# 200:	learn: 0.8890590	test: 0.7899794	best: 0.7899794 (200)	total: 16.2s	remaining: 24.1s
# 201:	learn: 0.8893289	test: 0.7903559	best: 0.7903559 (201)	total: 16.2s	remaining: 24s
# 202:	learn: 0.8896661	test: 0.7902017	best: 0.7903559 (201)	total: 16.3s	remaining: 23.9s
# 203:	learn: 0.8897842	test: 0.7904515	best: 0.7904515 (203)	total: 16.4s	remaining: 23.7s
# 204:	learn: 0.8899051	test: 0.7907350	best: 0.7907350 (204)	total: 16.4s	remaining: 23.6s
# 205:	learn: 0.8901624	test: 0.7907582	best: 0.7907582 (205)	total: 16.5s	remaining: 23.5s
# 206:	learn: 0.8903567	test: 0.7913392	best: 0.7913392 (206)	total: 16.6s	remaining: 23.5s
# 207:	learn: 0.8906179	test: 0.7914438	best: 0.7914438 (207)	total: 16.7s	remaining: 23.4s
# 208:	learn: 0.8907296	test: 0.7915569	best: 0.7915569 (208)	total: 16.8s	remaining: 23.4s
# 209:	learn: 0.8908810	test: 0.7915528	best: 0.7915569 (208)	total: 16.9s	remaining: 23.3s
# 210:	learn: 0.8910084	test: 0.7918001	best: 0.7918001 (210)	total: 16.9s	remaining: 23.1s
# 211:	learn: 0.8911655	test: 0.7923665	best: 0.7923665 (211)	total: 16.9s	remaining: 23s
# 212:	learn: 0.8914517	test: 0.7926033	best: 0.7926033 (212)	total: 17s	remaining: 22.9s
# 213:	learn: 0.8915498	test: 0.7928553	best: 0.7928553 (213)	total: 17.1s	remaining: 22.8s
# 214:	learn: 0.8918842	test: 0.7927959	best: 0.7928553 (213)	total: 17.2s	remaining: 22.7s
# 215:	learn: 0.8921255	test: 0.7930095	best: 0.7930095 (215)	total: 17.3s	remaining: 22.7s
# 216:	learn: 0.8922400	test: 0.7930006	best: 0.7930095 (215)	total: 17.3s	remaining: 22.6s
# 217:	learn: 0.8923730	test: 0.7931304	best: 0.7931304 (217)	total: 17.4s	remaining: 22.5s
# 218:	learn: 0.8924496	test: 0.7931852	best: 0.7931852 (218)	total: 17.4s	remaining: 22.4s
# 219:	learn: 0.8927727	test: 0.7931242	best: 0.7931852 (218)	total: 17.5s	remaining: 22.2s
# 220:	learn: 0.8929704	test: 0.7936486	best: 0.7936486 (220)	total: 17.6s	remaining: 22.2s
# 221:	learn: 0.8933500	test: 0.7937213	best: 0.7937213 (221)	total: 17.7s	remaining: 22.1s
# 222:	learn: 0.8937104	test: 0.7939750	best: 0.7939750 (222)	total: 17.7s	remaining: 22s
# 223:	learn: 0.8940863	test: 0.7939429	best: 0.7939750 (222)	total: 17.8s	remaining: 22s
# 224:	learn: 0.8943684	test: 0.7938510	best: 0.7939750 (222)	total: 17.9s	remaining: 21.9s
# 225:	learn: 0.8947054	test: 0.7941580	best: 0.7941580 (225)	total: 18s	remaining: 21.8s
# 226:	learn: 0.8947958	test: 0.7941593	best: 0.7941593 (226)	total: 18.1s	remaining: 21.7s
# 227:	learn: 0.8949318	test: 0.7941926	best: 0.7941926 (227)	total: 18.1s	remaining: 21.6s
# 228:	learn: 0.8955440	test: 0.7946195	best: 0.7946195 (228)	total: 18.2s	remaining: 21.6s
# 229:	learn: 0.8959388	test: 0.7945479	best: 0.7946195 (228)	total: 18.3s	remaining: 21.5s
# 230:	learn: 0.8960232	test: 0.7945376	best: 0.7946195 (228)	total: 18.4s	remaining: 21.4s
# 231:	learn: 0.8961745	test: 0.7948641	best: 0.7948641 (231)	total: 18.5s	remaining: 21.4s
# 232:	learn: 0.8961898	test: 0.7948868	best: 0.7948868 (232)	total: 18.6s	remaining: 21.3s
# 233:	learn: 0.8964129	test: 0.7955666	best: 0.7955666 (233)	total: 18.6s	remaining: 21.2s
# 234:	learn: 0.8964973	test: 0.7955718	best: 0.7955718 (234)	total: 18.7s	remaining: 21.1s
# 235:	learn: 0.8967986	test: 0.7958399	best: 0.7958399 (235)	total: 18.8s	remaining: 21s
# 236:	learn: 0.8968055	test: 0.7958364	best: 0.7958399 (235)	total: 18.8s	remaining: 20.9s
# 237:	learn: 0.8969035	test: 0.7960225	best: 0.7960225 (237)	total: 18.9s	remaining: 20.8s
# 238:	learn: 0.8970104	test: 0.7960309	best: 0.7960309 (238)	total: 19s	remaining: 20.7s
# 239:	learn: 0.8972789	test: 0.7959966	best: 0.7960309 (238)	total: 19.1s	remaining: 20.6s
# 240:	learn: 0.8974871	test: 0.7966264	best: 0.7966264 (240)	total: 19.1s	remaining: 20.6s
# 241:	learn: 0.8975529	test: 0.7964883	best: 0.7966264 (240)	total: 19.2s	remaining: 20.5s
# 242:	learn: 0.8977576	test: 0.7971169	best: 0.7971169 (242)	total: 19.3s	remaining: 20.4s
# 243:	learn: 0.8978619	test: 0.7975559	best: 0.7975559 (243)	total: 19.4s	remaining: 20.3s
# 244:	learn: 0.8979636	test: 0.7979875	best: 0.7979875 (244)	total: 19.4s	remaining: 20.2s
# 245:	learn: 0.8981793	test: 0.7982072	best: 0.7982072 (245)	total: 19.5s	remaining: 20.1s
# 246:	learn: 0.8985681	test: 0.7983532	best: 0.7983532 (246)	total: 19.6s	remaining: 20.1s
# 247:	learn: 0.8987544	test: 0.7989504	best: 0.7989504 (247)	total: 19.7s	remaining: 20s
# 248:	learn: 0.8989454	test: 0.7994573	best: 0.7994573 (248)	total: 19.7s	remaining: 19.9s
# 249:	learn: 0.8992498	test: 0.7994817	best: 0.7994817 (249)	total: 19.8s	remaining: 19.8s
# 250:	learn: 0.8993410	test: 0.7998821	best: 0.7998821 (250)	total: 19.9s	remaining: 19.7s
# 251:	learn: 0.8995147	test: 0.8004483	best: 0.8004483 (251)	total: 19.9s	remaining: 19.6s
# 252:	learn: 0.8995940	test: 0.8004727	best: 0.8004727 (252)	total: 20s	remaining: 19.5s
# 253:	learn: 0.8998126	test: 0.8004686	best: 0.8004727 (252)	total: 20.1s	remaining: 19.5s
# 254:	learn: 0.8999163	test: 0.8004694	best: 0.8004727 (252)	total: 20.2s	remaining: 19.4s
# 255:	learn: 0.9000007	test: 0.8008507	best: 0.8008507 (255)	total: 20.3s	remaining: 19.3s
# 256:	learn: 0.9001661	test: 0.8013946	best: 0.8013946 (256)	total: 20.3s	remaining: 19.2s
# 257:	learn: 0.9003106	test: 0.8015274	best: 0.8015274 (257)	total: 20.4s	remaining: 19.2s
# 258:	learn: 0.9003517	test: 0.8016436	best: 0.8016436 (258)	total: 20.5s	remaining: 19s
# 259:	learn: 0.9004546	test: 0.8019682	best: 0.8019682 (259)	total: 20.5s	remaining: 19s
# 260:	learn: 0.9005857	test: 0.8022441	best: 0.8022441 (260)	total: 20.6s	remaining: 18.9s
# 261:	learn: 0.9006377	test: 0.8023454	best: 0.8023454 (261)	total: 20.7s	remaining: 18.8s
# 262:	learn: 0.9008551	test: 0.8023054	best: 0.8023454 (261)	total: 20.8s	remaining: 18.7s
# 263:	learn: 0.9009340	test: 0.8024674	best: 0.8024674 (263)	total: 20.8s	remaining: 18.6s
# 264:	learn: 0.9011493	test: 0.8026748	best: 0.8026748 (264)	total: 20.9s	remaining: 18.5s
# 265:	learn: 0.9011802	test: 0.8027578	best: 0.8027578 (265)	total: 21s	remaining: 18.5s
# 266:	learn: 0.9012147	test: 0.8028535	best: 0.8028535 (266)	total: 21s	remaining: 18.4s
# 267:	learn: 0.9012938	test: 0.8030291	best: 0.8030291 (267)	total: 21.1s	remaining: 18.3s
# 268:	learn: 0.9013611	test: 0.8031831	best: 0.8031831 (268)	total: 21.2s	remaining: 18.2s
# 269:	learn: 0.9014333	test: 0.8033470	best: 0.8033470 (269)	total: 21.2s	remaining: 18.1s
# 270:	learn: 0.9018866	test: 0.8035223	best: 0.8035223 (270)	total: 21.3s	remaining: 18s
# 271:	learn: 0.9021989	test: 0.8033138	best: 0.8035223 (270)	total: 21.4s	remaining: 17.9s
# 272:	learn: 0.9025371	test: 0.8040843	best: 0.8040843 (272)	total: 21.5s	remaining: 17.9s
# 273:	learn: 0.9026070	test: 0.8041563	best: 0.8041563 (273)	total: 21.6s	remaining: 17.8s
# 274:	learn: 0.9033763	test: 0.8042407	best: 0.8042407 (274)	total: 21.7s	remaining: 17.8s
# 275:	learn: 0.9033835	test: 0.8042437	best: 0.8042437 (275)	total: 21.8s	remaining: 17.7s
# 276:	learn: 0.9034888	test: 0.8042353	best: 0.8042437 (275)	total: 21.9s	remaining: 17.6s
# 277:	learn: 0.9035764	test: 0.8043703	best: 0.8043703 (277)	total: 22s	remaining: 17.6s
# 278:	learn: 0.9037968	test: 0.8044103	best: 0.8044103 (278)	total: 22.1s	remaining: 17.5s
# 279:	learn: 0.9039955	test: 0.8045526	best: 0.8045526 (279)	total: 22.2s	remaining: 17.5s
# 280:	learn: 0.9040525	test: 0.8046386	best: 0.8046386 (280)	total: 22.3s	remaining: 17.4s
# 281:	learn: 0.9041128	test: 0.8049478	best: 0.8049478 (281)	total: 22.4s	remaining: 17.3s
# 282:	learn: 0.9042734	test: 0.8054051	best: 0.8054051 (282)	total: 22.4s	remaining: 17.2s
# 283:	learn: 0.9044278	test: 0.8059137	best: 0.8059137 (283)	total: 22.5s	remaining: 17.1s
# 284:	learn: 0.9044564	test: 0.8059749	best: 0.8059749 (284)	total: 22.6s	remaining: 17.1s
# 285:	learn: 0.9045486	test: 0.8061785	best: 0.8061785 (285)	total: 22.7s	remaining: 17s
# 286:	learn: 0.9046920	test: 0.8061899	best: 0.8061899 (286)	total: 22.8s	remaining: 16.9s
# 287:	learn: 0.9047392	test: 0.8063960	best: 0.8063960 (287)	total: 22.8s	remaining: 16.8s
# 288:	learn: 0.9048906	test: 0.8063066	best: 0.8063960 (287)	total: 22.9s	remaining: 16.7s
# 289:	learn: 0.9049193	test: 0.8063604	best: 0.8063960 (287)	total: 23s	remaining: 16.6s
# 290:	learn: 0.9054565	test: 0.8069080	best: 0.8069080 (290)	total: 23.1s	remaining: 16.6s
# 291:	learn: 0.9055975	test: 0.8070163	best: 0.8070163 (291)	total: 23.2s	remaining: 16.5s
# 292:	learn: 0.9057822	test: 0.8070444	best: 0.8070444 (292)	total: 23.3s	remaining: 16.4s
# 293:	learn: 0.9062426	test: 0.8071547	best: 0.8071547 (293)	total: 23.4s	remaining: 16.4s
# 294:	learn: 0.9062754	test: 0.8072252	best: 0.8072252 (294)	total: 23.5s	remaining: 16.3s
# 295:	learn: 0.9064083	test: 0.8076146	best: 0.8076146 (295)	total: 23.6s	remaining: 16.2s
# 296:	learn: 0.9064861	test: 0.8076801	best: 0.8076801 (296)	total: 23.7s	remaining: 16.2s
# 297:	learn: 0.9067486	test: 0.8075883	best: 0.8076801 (296)	total: 23.8s	remaining: 16.1s
# 298:	learn: 0.9068527	test: 0.8079795	best: 0.8079795 (298)	total: 23.9s	remaining: 16.1s
# 299:	learn: 0.9069216	test: 0.8079030	best: 0.8079795 (298)	total: 24s	remaining: 16s
# 300:	learn: 0.9069667	test: 0.8079601	best: 0.8079795 (298)	total: 24.1s	remaining: 15.9s
# 301:	learn: 0.9073626	test: 0.8082310	best: 0.8082310 (301)	total: 24.2s	remaining: 15.9s
# 302:	learn: 0.9074421	test: 0.8083758	best: 0.8083758 (302)	total: 24.3s	remaining: 15.8s
# 303:	learn: 0.9074811	test: 0.8084335	best: 0.8084335 (303)	total: 24.4s	remaining: 15.7s
# 304:	learn: 0.9081278	test: 0.8088860	best: 0.8088860 (304)	total: 24.5s	remaining: 15.7s
# 305:	learn: 0.9082008	test: 0.8090429	best: 0.8090429 (305)	total: 24.6s	remaining: 15.6s
# 306:	learn: 0.9085272	test: 0.8092003	best: 0.8092003 (306)	total: 24.7s	remaining: 15.5s
# 307:	learn: 0.9085653	test: 0.8092029	best: 0.8092029 (307)	total: 24.8s	remaining: 15.5s
# 308:	learn: 0.9086601	test: 0.8095663	best: 0.8095663 (308)	total: 24.9s	remaining: 15.4s
# 309:	learn: 0.9087933	test: 0.8096198	best: 0.8096198 (309)	total: 25s	remaining: 15.3s
# 310:	learn: 0.9091568	test: 0.8097954	best: 0.8097954 (310)	total: 25.1s	remaining: 15.2s
# 311:	learn: 0.9092521	test: 0.8101455	best: 0.8101455 (311)	total: 25.2s	remaining: 15.2s
# 312:	learn: 0.9094518	test: 0.8102454	best: 0.8102454 (312)	total: 25.3s	remaining: 15.1s
# 313:	learn: 0.9094957	test: 0.8102702	best: 0.8102702 (313)	total: 25.4s	remaining: 15s
# 314:	learn: 0.9095253	test: 0.8103879	best: 0.8103879 (314)	total: 25.5s	remaining: 15s
# 315:	learn: 0.9095670	test: 0.8104208	best: 0.8104208 (315)	total: 25.6s	remaining: 14.9s
# 316:	learn: 0.9096959	test: 0.8107672	best: 0.8107672 (316)	total: 25.7s	remaining: 14.8s
# 317:	learn: 0.9097786	test: 0.8110993	best: 0.8110993 (317)	total: 25.8s	remaining: 14.8s
# 318:	learn: 0.9098755	test: 0.8108149	best: 0.8110993 (317)	total: 25.9s	remaining: 14.7s
# 319:	learn: 0.9099547	test: 0.8108424	best: 0.8110993 (317)	total: 26s	remaining: 14.6s
# 320:	learn: 0.9100761	test: 0.8107783	best: 0.8110993 (317)	total: 26.1s	remaining: 14.5s
# 321:	learn: 0.9101672	test: 0.8109009	best: 0.8110993 (317)	total: 26.2s	remaining: 14.5s
# 322:	learn: 0.9102581	test: 0.8109306	best: 0.8110993 (317)	total: 26.2s	remaining: 14.4s
# 323:	learn: 0.9102691	test: 0.8109456	best: 0.8110993 (317)	total: 26.3s	remaining: 14.3s
# 324:	learn: 0.9103521	test: 0.8112625	best: 0.8112625 (324)	total: 26.4s	remaining: 14.2s
# 325:	learn: 0.9104304	test: 0.8115730	best: 0.8115730 (325)	total: 26.5s	remaining: 14.2s
# 326:	learn: 0.9106956	test: 0.8116210	best: 0.8116210 (326)	total: 26.7s	remaining: 14.1s
# 327:	learn: 0.9108567	test: 0.8115478	best: 0.8116210 (326)	total: 26.8s	remaining: 14s
# 328:	learn: 0.9109727	test: 0.8116533	best: 0.8116533 (328)	total: 26.8s	remaining: 13.9s
# 329:	learn: 0.9112177	test: 0.8121068	best: 0.8121068 (329)	total: 26.9s	remaining: 13.9s
# 330:	learn: 0.9112509	test: 0.8121735	best: 0.8121735 (330)	total: 27s	remaining: 13.8s
# 331:	learn: 0.9116020	test: 0.8125304	best: 0.8125304 (331)	total: 27.1s	remaining: 13.7s
# 332:	learn: 0.9117478	test: 0.8124245	best: 0.8125304 (331)	total: 27.2s	remaining: 13.7s
# 333:	learn: 0.9117740	test: 0.8124654	best: 0.8125304 (331)	total: 27.4s	remaining: 13.6s
# 334:	learn: 0.9117801	test: 0.8124756	best: 0.8125304 (331)	total: 27.4s	remaining: 13.5s
# 335:	learn: 0.9119811	test: 0.8124452	best: 0.8125304 (331)	total: 27.5s	remaining: 13.4s
# 336:	learn: 0.9121461	test: 0.8126489	best: 0.8126489 (336)	total: 27.6s	remaining: 13.3s
# 337:	learn: 0.9122177	test: 0.8128480	best: 0.8128480 (337)	total: 27.7s	remaining: 13.3s
# 338:	learn: 0.9124748	test: 0.8129959	best: 0.8129959 (338)	total: 27.7s	remaining: 13.2s
# 339:	learn: 0.9125673	test: 0.8131831	best: 0.8131831 (339)	total: 27.8s	remaining: 13.1s
# 340:	learn: 0.9126067	test: 0.8132788	best: 0.8132788 (340)	total: 27.9s	remaining: 13s
# 341:	learn: 0.9126596	test: 0.8133854	best: 0.8133854 (341)	total: 28s	remaining: 13s
# 342:	learn: 0.9127950	test: 0.8132927	best: 0.8133854 (341)	total: 28.1s	remaining: 12.9s
# 343:	learn: 0.9128775	test: 0.8135702	best: 0.8135702 (343)	total: 28.3s	remaining: 12.8s
# 344:	learn: 0.9129353	test: 0.8138395	best: 0.8138395 (344)	total: 28.3s	remaining: 12.7s
# 345:	learn: 0.9130226	test: 0.8138838	best: 0.8138838 (345)	total: 28.4s	remaining: 12.6s
# 346:	learn: 0.9133920	test: 0.8143876	best: 0.8143876 (346)	total: 28.5s	remaining: 12.6s
# 347:	learn: 0.9135786	test: 0.8141157	best: 0.8143876 (346)	total: 28.6s	remaining: 12.5s
# 348:	learn: 0.9137596	test: 0.8144023	best: 0.8144023 (348)	total: 28.7s	remaining: 12.4s
# 349:	learn: 0.9138204	test: 0.8146608	best: 0.8146608 (349)	total: 28.9s	remaining: 12.4s
# 350:	learn: 0.9139922	test: 0.8146451	best: 0.8146608 (349)	total: 29s	remaining: 12.3s
# 351:	learn: 0.9140087	test: 0.8146908	best: 0.8146908 (351)	total: 29s	remaining: 12.2s
# 352:	learn: 0.9140655	test: 0.8149403	best: 0.8149403 (352)	total: 29.1s	remaining: 12.1s
# 353:	learn: 0.9140837	test: 0.8149832	best: 0.8149832 (353)	total: 29.2s	remaining: 12s
# 354:	learn: 0.9141340	test: 0.8152288	best: 0.8152288 (354)	total: 29.3s	remaining: 12s
# 355:	learn: 0.9143762	test: 0.8153284	best: 0.8153284 (355)	total: 29.4s	remaining: 11.9s
# 356:	learn: 0.9144323	test: 0.8155683	best: 0.8155683 (356)	total: 29.5s	remaining: 11.8s
# 357:	learn: 0.9144813	test: 0.8158025	best: 0.8158025 (357)	total: 29.6s	remaining: 11.7s
# 358:	learn: 0.9145604	test: 0.8158030	best: 0.8158030 (358)	total: 29.6s	remaining: 11.6s
# 359:	learn: 0.9146157	test: 0.8160329	best: 0.8160329 (359)	total: 29.7s	remaining: 11.6s
# 360:	learn: 0.9147254	test: 0.8161061	best: 0.8161061 (360)	total: 29.8s	remaining: 11.5s
# 361:	learn: 0.9148015	test: 0.8160761	best: 0.8161061 (360)	total: 29.9s	remaining: 11.4s
# 362:	learn: 0.9148571	test: 0.8162941	best: 0.8162941 (362)	total: 30s	remaining: 11.3s
# 363:	learn: 0.9149115	test: 0.8163024	best: 0.8163024 (363)	total: 30.1s	remaining: 11.3s
# 364:	learn: 0.9149649	test: 0.8163621	best: 0.8163621 (364)	total: 30.3s	remaining: 11.2s
# 365:	learn: 0.9150552	test: 0.8163172	best: 0.8163621 (364)	total: 30.3s	remaining: 11.1s
# 366:	learn: 0.9151114	test: 0.8163032	best: 0.8163621 (364)	total: 30.4s	remaining: 11s
# 367:	learn: 0.9151876	test: 0.8163062	best: 0.8163621 (364)	total: 30.5s	remaining: 11s
# 368:	learn: 0.9152149	test: 0.8163159	best: 0.8163621 (364)	total: 30.7s	remaining: 10.9s
# 369:	learn: 0.9152591	test: 0.8165187	best: 0.8165187 (369)	total: 30.8s	remaining: 10.8s
# 370:	learn: 0.9154149	test: 0.8168369	best: 0.8168369 (370)	total: 30.8s	remaining: 10.7s
# 371:	learn: 0.9155472	test: 0.8168927	best: 0.8168927 (371)	total: 30.9s	remaining: 10.6s
# 372:	learn: 0.9156161	test: 0.8168802	best: 0.8168927 (371)	total: 31s	remaining: 10.6s
# 373:	learn: 0.9156705	test: 0.8169356	best: 0.8169356 (373)	total: 31.1s	remaining: 10.5s
# 374:	learn: 0.9156895	test: 0.8170765	best: 0.8170765 (374)	total: 31.2s	remaining: 10.4s
# 375:	learn: 0.9157533	test: 0.8171585	best: 0.8171585 (375)	total: 31.4s	remaining: 10.3s
# 376:	learn: 0.9158023	test: 0.8171733	best: 0.8171733 (376)	total: 31.5s	remaining: 10.3s
# 377:	learn: 0.9158759	test: 0.8171764	best: 0.8171764 (377)	total: 31.6s	remaining: 10.2s
# 378:	learn: 0.9160505	test: 0.8170686	best: 0.8171764 (377)	total: 31.7s	remaining: 10.1s
# 379:	learn: 0.9160975	test: 0.8172718	best: 0.8172718 (379)	total: 31.8s	remaining: 10s
# 380:	learn: 0.9161363	test: 0.8172647	best: 0.8172718 (379)	total: 31.9s	remaining: 9.96s
# 381:	learn: 0.9161738	test: 0.8173211	best: 0.8173211 (381)	total: 32s	remaining: 9.88s
# 382:	learn: 0.9163078	test: 0.8174600	best: 0.8174600 (382)	total: 32.1s	remaining: 9.81s
# 383:	learn: 0.9163639	test: 0.8176019	best: 0.8176019 (383)	total: 32.2s	remaining: 9.73s
# 384:	learn: 0.9164141	test: 0.8175594	best: 0.8176019 (383)	total: 32.3s	remaining: 9.65s
# 385:	learn: 0.9165345	test: 0.8176144	best: 0.8176144 (385)	total: 32.4s	remaining: 9.57s
# 386:	learn: 0.9166003	test: 0.8176003	best: 0.8176144 (385)	total: 32.5s	remaining: 9.49s
# 387:	learn: 0.9167226	test: 0.8179736	best: 0.8179736 (387)	total: 32.6s	remaining: 9.41s
# 388:	learn: 0.9168131	test: 0.8179649	best: 0.8179736 (387)	total: 32.7s	remaining: 9.34s
# 389:	learn: 0.9169060	test: 0.8179320	best: 0.8179736 (387)	total: 32.8s	remaining: 9.26s
# 390:	learn: 0.9170045	test: 0.8180078	best: 0.8180078 (390)	total: 32.9s	remaining: 9.18s
# 391:	learn: 0.9170382	test: 0.8180737	best: 0.8180737 (391)	total: 33.1s	remaining: 9.11s
# 392:	learn: 0.9172449	test: 0.8181373	best: 0.8181373 (392)	total: 33.2s	remaining: 9.03s
# 393:	learn: 0.9172745	test: 0.8181842	best: 0.8181842 (393)	total: 33.3s	remaining: 8.95s
# 394:	learn: 0.9173267	test: 0.8181872	best: 0.8181872 (394)	total: 33.4s	remaining: 8.88s
# 395:	learn: 0.9173889	test: 0.8181594	best: 0.8181872 (394)	total: 33.5s	remaining: 8.8s
# 396:	learn: 0.9174169	test: 0.8182261	best: 0.8182261 (396)	total: 33.6s	remaining: 8.73s
# 397:	learn: 0.9174930	test: 0.8181830	best: 0.8182261 (396)	total: 33.7s	remaining: 8.64s
# 398:	learn: 0.9175991	test: 0.8181146	best: 0.8182261 (396)	total: 33.8s	remaining: 8.57s
# 399:	learn: 0.9176792	test: 0.8181060	best: 0.8182261 (396)	total: 34s	remaining: 8.49s
# 400:	learn: 0.9177316	test: 0.8181124	best: 0.8182261 (396)	total: 34.1s	remaining: 8.41s
# 401:	learn: 0.9177666	test: 0.8182983	best: 0.8182983 (401)	total: 34.2s	remaining: 8.33s
# 402:	learn: 0.9177985	test: 0.8184609	best: 0.8184609 (402)	total: 34.3s	remaining: 8.25s
# 403:	learn: 0.9178640	test: 0.8187301	best: 0.8187301 (403)	total: 34.4s	remaining: 8.17s
# 404:	learn: 0.9179157	test: 0.8186941	best: 0.8187301 (403)	total: 34.5s	remaining: 8.09s
# 405:	learn: 0.9180124	test: 0.8187303	best: 0.8187303 (405)	total: 34.6s	remaining: 8.01s
# 406:	learn: 0.9180841	test: 0.8187144	best: 0.8187303 (405)	total: 34.7s	remaining: 7.93s
# 407:	learn: 0.9181178	test: 0.8188791	best: 0.8188791 (407)	total: 34.8s	remaining: 7.85s
# 408:	learn: 0.9182165	test: 0.8189898	best: 0.8189898 (408)	total: 34.9s	remaining: 7.77s
# 409:	learn: 0.9182582	test: 0.8189540	best: 0.8189898 (408)	total: 35s	remaining: 7.69s
# 410:	learn: 0.9183270	test: 0.8188882	best: 0.8189898 (408)	total: 35.1s	remaining: 7.61s
# 411:	learn: 0.9184497	test: 0.8188772	best: 0.8189898 (408)	total: 35.2s	remaining: 7.53s
# 412:	learn: 0.9184781	test: 0.8188078	best: 0.8189898 (408)	total: 35.4s	remaining: 7.45s
# 413:	learn: 0.9185853	test: 0.8188661	best: 0.8189898 (408)	total: 35.5s	remaining: 7.37s
# 414:	learn: 0.9186401	test: 0.8189237	best: 0.8189898 (408)	total: 35.6s	remaining: 7.29s
# 415:	learn: 0.9186867	test: 0.8193053	best: 0.8193053 (415)	total: 35.7s	remaining: 7.21s
# 416:	learn: 0.9187255	test: 0.8192371	best: 0.8193053 (415)	total: 35.8s	remaining: 7.12s
# 417:	learn: 0.9190116	test: 0.8192383	best: 0.8193053 (415)	total: 35.9s	remaining: 7.04s
# 418:	learn: 0.9190713	test: 0.8191828	best: 0.8193053 (415)	total: 36s	remaining: 6.96s
# 419:	learn: 0.9190998	test: 0.8193281	best: 0.8193281 (419)	total: 36.1s	remaining: 6.88s
# 420:	learn: 0.9195089	test: 0.8191276	best: 0.8193281 (419)	total: 36.2s	remaining: 6.79s
# 421:	learn: 0.9195805	test: 0.8191363	best: 0.8193281 (419)	total: 36.3s	remaining: 6.72s
# 422:	learn: 0.9196054	test: 0.8192766	best: 0.8193281 (419)	total: 36.4s	remaining: 6.63s
# 423:	learn: 0.9197941	test: 0.8191397	best: 0.8193281 (419)	total: 36.5s	remaining: 6.55s
# 424:	learn: 0.9198196	test: 0.8192795	best: 0.8193281 (419)	total: 36.6s	remaining: 6.47s
# 425:	learn: 0.9198440	test: 0.8194042	best: 0.8194042 (425)	total: 36.7s	remaining: 6.38s
# 426:	learn: 0.9199027	test: 0.8195295	best: 0.8195295 (426)	total: 36.9s	remaining: 6.3s
# 427:	learn: 0.9199371	test: 0.8194558	best: 0.8195295 (426)	total: 37s	remaining: 6.22s
# 428:	learn: 0.9200187	test: 0.8195742	best: 0.8195742 (428)	total: 37.1s	remaining: 6.13s
# 429:	learn: 0.9200603	test: 0.8195239	best: 0.8195742 (428)	total: 37.2s	remaining: 6.05s
# 430:	learn: 0.9200878	test: 0.8197015	best: 0.8197015 (430)	total: 37.3s	remaining: 5.97s
# 431:	learn: 0.9203144	test: 0.8196210	best: 0.8197015 (430)	total: 37.4s	remaining: 5.89s
# 432:	learn: 0.9203570	test: 0.8195953	best: 0.8197015 (430)	total: 37.5s	remaining: 5.8s
# 433:	learn: 0.9203980	test: 0.8195529	best: 0.8197015 (430)	total: 37.6s	remaining: 5.72s
# 434:	learn: 0.9206186	test: 0.8198340	best: 0.8198340 (434)	total: 37.7s	remaining: 5.64s
# 435:	learn: 0.9206807	test: 0.8197273	best: 0.8198340 (434)	total: 37.8s	remaining: 5.55s
# 436:	learn: 0.9206996	test: 0.8198493	best: 0.8198493 (436)	total: 38s	remaining: 5.47s
# 437:	learn: 0.9208817	test: 0.8199405	best: 0.8199405 (437)	total: 38.1s	remaining: 5.39s
# 438:	learn: 0.9209311	test: 0.8198888	best: 0.8199405 (437)	total: 38.2s	remaining: 5.31s
# 439:	learn: 0.9209448	test: 0.8198075	best: 0.8199405 (437)	total: 38.3s	remaining: 5.22s
# 440:	learn: 0.9209747	test: 0.8197548	best: 0.8199405 (437)	total: 38.4s	remaining: 5.14s
# 441:	learn: 0.9210227	test: 0.8196580	best: 0.8199405 (437)	total: 38.5s	remaining: 5.05s
# 442:	learn: 0.9210651	test: 0.8196041	best: 0.8199405 (437)	total: 38.6s	remaining: 4.97s
# 443:	learn: 0.9211010	test: 0.8195156	best: 0.8199405 (437)	total: 38.7s	remaining: 4.88s
# 444:	learn: 0.9211210	test: 0.8196288	best: 0.8199405 (437)	total: 38.8s	remaining: 4.8s
# 445:	learn: 0.9211302	test: 0.8197067	best: 0.8199405 (437)	total: 38.9s	remaining: 4.71s
# 446:	learn: 0.9212191	test: 0.8197011	best: 0.8199405 (437)	total: 39s	remaining: 4.63s
# 447:	learn: 0.9212321	test: 0.8197601	best: 0.8199405 (437)	total: 39.1s	remaining: 4.54s
# 448:	learn: 0.9212771	test: 0.8195977	best: 0.8199405 (437)	total: 39.2s	remaining: 4.46s
# 449:	learn: 0.9213399	test: 0.8195366	best: 0.8199405 (437)	total: 39.4s	remaining: 4.37s
# 450:	learn: 0.9213998	test: 0.8196612	best: 0.8199405 (437)	total: 39.5s	remaining: 4.29s
# 451:	learn: 0.9214404	test: 0.8196430	best: 0.8199405 (437)	total: 39.6s	remaining: 4.2s
# 452:	learn: 0.9215106	test: 0.8199757	best: 0.8199757 (452)	total: 39.7s	remaining: 4.12s
# 453:	learn: 0.9215381	test: 0.8199760	best: 0.8199760 (453)	total: 39.8s	remaining: 4.03s
# 454:	learn: 0.9216677	test: 0.8202391	best: 0.8202391 (454)	total: 39.9s	remaining: 3.94s
# 455:	learn: 0.9217164	test: 0.8202419	best: 0.8202419 (455)	total: 40s	remaining: 3.86s
# 456:	learn: 0.9217484	test: 0.8202069	best: 0.8202419 (455)	total: 40.1s	remaining: 3.77s
# 457:	learn: 0.9217982	test: 0.8201357	best: 0.8202419 (455)	total: 40.2s	remaining: 3.69s
# 458:	learn: 0.9218135	test: 0.8202314	best: 0.8202419 (455)	total: 40.3s	remaining: 3.6s
# 459:	learn: 0.9220451	test: 0.8203645	best: 0.8203645 (459)	total: 40.4s	remaining: 3.51s
# 460:	learn: 0.9221013	test: 0.8203894	best: 0.8203894 (460)	total: 40.5s	remaining: 3.43s
# 461:	learn: 0.9221984	test: 0.8206486	best: 0.8206486 (461)	total: 40.6s	remaining: 3.34s
# 462:	learn: 0.9222178	test: 0.8207119	best: 0.8207119 (462)	total: 40.7s	remaining: 3.26s
# 463:	learn: 0.9222508	test: 0.8206848	best: 0.8207119 (462)	total: 40.8s	remaining: 3.17s
# 464:	learn: 0.9222652	test: 0.8207802	best: 0.8207802 (464)	total: 41s	remaining: 3.08s
# 465:	learn: 0.9223613	test: 0.8208463	best: 0.8208463 (465)	total: 41.1s	remaining: 3s
# 466:	learn: 0.9223986	test: 0.8207892	best: 0.8208463 (465)	total: 41.2s	remaining: 2.91s
# 467:	learn: 0.9225474	test: 0.8209701	best: 0.8209701 (467)	total: 41.3s	remaining: 2.82s
# 468:	learn: 0.9225815	test: 0.8209608	best: 0.8209701 (467)	total: 41.4s	remaining: 2.74s
# 469:	learn: 0.9226176	test: 0.8209032	best: 0.8209701 (467)	total: 41.5s	remaining: 2.65s
# 470:	learn: 0.9226462	test: 0.8208023	best: 0.8209701 (467)	total: 41.6s	remaining: 2.56s
# 471:	learn: 0.9227986	test: 0.8211031	best: 0.8211031 (471)	total: 41.7s	remaining: 2.47s
# 472:	learn: 0.9228107	test: 0.8211918	best: 0.8211918 (472)	total: 41.8s	remaining: 2.39s
# 473:	learn: 0.9228186	test: 0.8212175	best: 0.8212175 (473)	total: 41.9s	remaining: 2.3s
# 474:	learn: 0.9228465	test: 0.8211730	best: 0.8212175 (473)	total: 42s	remaining: 2.21s
# 475:	learn: 0.9230104	test: 0.8213314	best: 0.8213314 (475)	total: 42.2s	remaining: 2.13s
# 476:	learn: 0.9230316	test: 0.8212814	best: 0.8213314 (475)	total: 42.3s	remaining: 2.04s
# 477:	learn: 0.9232829	test: 0.8212493	best: 0.8213314 (475)	total: 42.4s	remaining: 1.95s
# 478:	learn: 0.9237087	test: 0.8216426	best: 0.8216426 (478)	total: 42.5s	remaining: 1.86s
# 479:	learn: 0.9237183	test: 0.8217068	best: 0.8217068 (479)	total: 42.6s	remaining: 1.77s
# 480:	learn: 0.9237907	test: 0.8217011	best: 0.8217068 (479)	total: 42.7s	remaining: 1.69s
# 481:	learn: 0.9238063	test: 0.8217016	best: 0.8217068 (479)	total: 42.8s	remaining: 1.6s
# 482:	learn: 0.9238267	test: 0.8218175	best: 0.8218175 (482)	total: 42.9s	remaining: 1.51s
# 483:	learn: 0.9238458	test: 0.8217901	best: 0.8218175 (482)	total: 43s	remaining: 1.42s
# 484:	learn: 0.9239120	test: 0.8217944	best: 0.8218175 (482)	total: 43.1s	remaining: 1.33s
# 485:	learn: 0.9239377	test: 0.8217637	best: 0.8218175 (482)	total: 43.2s	remaining: 1.25s
# 486:	learn: 0.9239481	test: 0.8217589	best: 0.8218175 (482)	total: 43.3s	remaining: 1.16s
# 487:	learn: 0.9239609	test: 0.8218525	best: 0.8218525 (487)	total: 43.5s	remaining: 1.07s
# 488:	learn: 0.9239924	test: 0.8218027	best: 0.8218525 (487)	total: 43.6s	remaining: 980ms
# 489:	learn: 0.9240028	test: 0.8218791	best: 0.8218791 (489)	total: 43.7s	remaining: 891ms
# 490:	learn: 0.9240276	test: 0.8218258	best: 0.8218791 (489)	total: 43.8s	remaining: 802ms
# 491:	learn: 0.9240391	test: 0.8219012	best: 0.8219012 (491)	total: 43.9s	remaining: 713ms
# 492:	learn: 0.9241790	test: 0.8219358	best: 0.8219358 (492)	total: 44s	remaining: 625ms
# 493:	learn: 0.9242048	test: 0.8219469	best: 0.8219469 (493)	total: 44.1s	remaining: 536ms
# 494:	learn: 0.9244242	test: 0.8219075	best: 0.8219469 (493)	total: 44.2s	remaining: 447ms
# 495:	learn: 0.9244546	test: 0.8217941	best: 0.8219469 (493)	total: 44.3s	remaining: 357ms
# 496:	learn: 0.9244771	test: 0.8217937	best: 0.8219469 (493)	total: 44.4s	remaining: 268ms
# 497:	learn: 0.9244833	test: 0.8218253	best: 0.8219469 (493)	total: 44.5s	remaining: 179ms
# 498:	learn: 0.9245125	test: 0.8218261	best: 0.8219469 (493)	total: 44.6s	remaining: 89.4ms
# 499:	learn: 0.9245224	test: 0.8218938	best: 0.8219469 (493)	total: 44.7s	remaining: 0us
#
# bestTest = 0.8219469005
# bestIteration = 493
#
# Shrink model to first 494 iterations.

# %% [markdown]
# Что мы видим на экране выше?
#
# * в первой колонке значение выбранной метрики, в нашей случае - $R^2$, на тренировочной выборке
# * во второй колонке - на валидационной выборке
# * в третьей колонке мы видим лучший результат на валидации за все обучение и номер соответствующей итерации
# * в четвертой колонке общее кол-во потраченного времени на обучение
# * в пятой колонке оставшее на обучение время

# %% [markdown]
# Что делать дальше?
#
# * Обучаем модель с разными параметрами (пока не надоест) пока не добьемся наилучшего результата на валидационной выборке
# * Далее, смотрим на какой итерации был наилучший результат и обучаемся на объединение тренировочной и валидационной выборки с ограничением до этой итерации
# * Делаем предикт на тестовой выборке
# * Считаем скор (если настоящие значения целевой переменной доступны)

# %%
# объединяем тренировочную и валидационную выборки в один сет 
X_train_new = pd.concat([X_train, X_val], axis=0)
y_train_new = pd.concat([y_train, y_val], axis=0)

# %%
# используем конструктор Pool
train_data = Pool(X_train_new, y_train_new, cat_features=cat_features)

# %%
# задаем параметры модели: те же, что и для наилучшей выбранной модели, но с урезанным кол-вом итерации до наилучшей итерации по выбранной модели
params={'iterations' : 494,
        'learning_rate' : 0.03,
        'eval_metric' : 'R2',
        'depth' : 5,
        'verbose' : True
        }

# %%
# определяем и обучаем модель
model = CatBoostRegressor(**params)
model.fit(train_data)
# Out:
# 0:	learn: 0.0050129	total: 70.3ms	remaining: 34.6s
# 1:	learn: 0.0105715	total: 146ms	remaining: 36s
# 2:	learn: 0.0140408	total: 247ms	remaining: 40.4s
# 3:	learn: 0.0192710	total: 345ms	remaining: 42.3s
# 4:	learn: 0.0248677	total: 434ms	remaining: 42.5s
# 5:	learn: 0.0304701	total: 521ms	remaining: 42.4s
# 6:	learn: 0.0353528	total: 613ms	remaining: 42.6s
# 7:	learn: 0.0410780	total: 697ms	remaining: 42.4s
# 8:	learn: 0.0457823	total: 784ms	remaining: 42.3s
# 9:	learn: 0.0522430	total: 837ms	remaining: 40.5s
# 10:	learn: 0.0546811	total: 854ms	remaining: 37.5s
# 11:	learn: 0.0622411	total: 919ms	remaining: 36.9s
# 12:	learn: 0.0694814	total: 980ms	remaining: 36.3s
# 13:	learn: 0.0777871	total: 1.09s	remaining: 37.5s
# 14:	learn: 0.0847594	total: 1.14s	remaining: 36.4s
# 15:	learn: 0.0915871	total: 1.21s	remaining: 36.2s
# 16:	learn: 0.1008455	total: 1.27s	remaining: 35.7s
# 17:	learn: 0.1090001	total: 1.36s	remaining: 36.1s
# 18:	learn: 0.1195271	total: 1.44s	remaining: 36.1s
# 19:	learn: 0.1298374	total: 1.53s	remaining: 36.4s
# 20:	learn: 0.1416032	total: 1.62s	remaining: 36.4s
# 21:	learn: 0.1539698	total: 1.69s	remaining: 36.3s
# 22:	learn: 0.1649985	total: 1.73s	remaining: 35.4s
# 23:	learn: 0.1762641	total: 1.78s	remaining: 34.9s
# 24:	learn: 0.1867874	total: 1.84s	remaining: 34.5s
# 25:	learn: 0.1988556	total: 1.92s	remaining: 34.6s
# 26:	learn: 0.2091540	total: 2s	remaining: 34.7s
# 27:	learn: 0.2212419	total: 2.07s	remaining: 34.4s
# 28:	learn: 0.2327708	total: 2.13s	remaining: 34.1s
# 29:	learn: 0.2458278	total: 2.21s	remaining: 34.1s
# 30:	learn: 0.2580859	total: 2.28s	remaining: 34.1s
# 31:	learn: 0.2708270	total: 2.36s	remaining: 34.1s
# 32:	learn: 0.2844677	total: 2.46s	remaining: 34.3s
# 33:	learn: 0.2986642	total: 2.54s	remaining: 34.4s
# 34:	learn: 0.3118442	total: 2.6s	remaining: 34.2s
# 35:	learn: 0.3251862	total: 2.68s	remaining: 34.1s
# 36:	learn: 0.3389502	total: 2.76s	remaining: 34s
# 37:	learn: 0.3512520	total: 2.8s	remaining: 33.6s
# 38:	learn: 0.3650262	total: 2.87s	remaining: 33.5s
# 39:	learn: 0.3780049	total: 2.97s	remaining: 33.7s
# 40:	learn: 0.3913618	total: 3.08s	remaining: 34.1s
# 41:	learn: 0.4027530	total: 3.18s	remaining: 34.2s
# 42:	learn: 0.4146802	total: 3.23s	remaining: 33.9s
# 43:	learn: 0.4282621	total: 3.29s	remaining: 33.7s
# 44:	learn: 0.4412862	total: 3.39s	remaining: 33.8s
# 45:	learn: 0.4551199	total: 3.47s	remaining: 33.8s
# 46:	learn: 0.4663711	total: 3.58s	remaining: 34.1s
# 47:	learn: 0.4777108	total: 3.63s	remaining: 33.8s
# 48:	learn: 0.4893716	total: 3.7s	remaining: 33.6s
# 49:	learn: 0.5010003	total: 3.77s	remaining: 33.4s
# 50:	learn: 0.5116687	total: 3.85s	remaining: 33.4s
# 51:	learn: 0.5233669	total: 3.93s	remaining: 33.4s
# 52:	learn: 0.5353672	total: 4.04s	remaining: 33.6s
# 53:	learn: 0.5446485	total: 4.13s	remaining: 33.7s
# 54:	learn: 0.5558677	total: 4.2s	remaining: 33.5s
# 55:	learn: 0.5673132	total: 4.29s	remaining: 33.6s
# 56:	learn: 0.5753588	total: 4.37s	remaining: 33.5s
# 57:	learn: 0.5837300	total: 4.41s	remaining: 33.1s
# 58:	learn: 0.5930494	total: 4.48s	remaining: 33.1s
# 59:	learn: 0.6024211	total: 4.57s	remaining: 33.1s
# 60:	learn: 0.6111829	total: 4.67s	remaining: 33.1s
# 61:	learn: 0.6202298	total: 4.76s	remaining: 33.2s
# 62:	learn: 0.6297403	total: 4.86s	remaining: 33.3s
# 63:	learn: 0.6371918	total: 4.93s	remaining: 33.1s
# 64:	learn: 0.6444473	total: 4.99s	remaining: 32.9s
# 65:	learn: 0.6519400	total: 5.06s	remaining: 32.8s
# 66:	learn: 0.6581259	total: 5.13s	remaining: 32.7s
# 67:	learn: 0.6665881	total: 5.21s	remaining: 32.6s
# 68:	learn: 0.6730329	total: 5.3s	remaining: 32.6s
# 69:	learn: 0.6799285	total: 5.39s	remaining: 32.7s
# 70:	learn: 0.6873358	total: 5.49s	remaining: 32.7s
# 71:	learn: 0.6928593	total: 5.54s	remaining: 32.5s
# 72:	learn: 0.6986126	total: 5.61s	remaining: 32.3s
# 73:	learn: 0.7046076	total: 5.68s	remaining: 32.2s
# 74:	learn: 0.7108145	total: 5.78s	remaining: 32.3s
# 75:	learn: 0.7169348	total: 5.86s	remaining: 32.2s
# 76:	learn: 0.7231802	total: 5.94s	remaining: 32.2s
# 77:	learn: 0.7284979	total: 6.02s	remaining: 32.1s
# 78:	learn: 0.7326165	total: 6.1s	remaining: 32s
# 79:	learn: 0.7369427	total: 6.19s	remaining: 32s
# 80:	learn: 0.7415431	total: 6.29s	remaining: 32.1s
# 81:	learn: 0.7455318	total: 6.39s	remaining: 32.1s
# 82:	learn: 0.7501616	total: 6.47s	remaining: 32.1s
# 83:	learn: 0.7535098	total: 6.54s	remaining: 31.9s
# 84:	learn: 0.7574282	total: 6.6s	remaining: 31.7s
# 85:	learn: 0.7614229	total: 6.67s	remaining: 31.7s
# 86:	learn: 0.7644976	total: 6.72s	remaining: 31.5s
# 87:	learn: 0.7679031	total: 6.77s	remaining: 31.3s
# 88:	learn: 0.7714393	total: 6.85s	remaining: 31.2s
# 89:	learn: 0.7746155	total: 6.93s	remaining: 31.1s
# 90:	learn: 0.7773529	total: 7.02s	remaining: 31.1s
# 91:	learn: 0.7801508	total: 7.09s	remaining: 31s
# 92:	learn: 0.7826281	total: 7.17s	remaining: 30.9s
# 93:	learn: 0.7846819	total: 7.22s	remaining: 30.7s
# 94:	learn: 0.7879683	total: 7.31s	remaining: 30.7s
# 95:	learn: 0.7909131	total: 7.4s	remaining: 30.7s
# 96:	learn: 0.7930678	total: 7.46s	remaining: 30.6s
# 97:	learn: 0.7959442	total: 7.54s	remaining: 30.5s
# 98:	learn: 0.7993111	total: 7.63s	remaining: 30.5s
# 99:	learn: 0.8023089	total: 7.72s	remaining: 30.4s
# 100:	learn: 0.8056438	total: 7.8s	remaining: 30.3s
# 101:	learn: 0.8075902	total: 7.88s	remaining: 30.3s
# 102:	learn: 0.8098181	total: 7.95s	remaining: 30.2s
# 103:	learn: 0.8122669	total: 8.03s	remaining: 30.1s
# 104:	learn: 0.8148429	total: 8.14s	remaining: 30.2s
# 105:	learn: 0.8172192	total: 8.26s	remaining: 30.2s
# 106:	learn: 0.8193474	total: 8.35s	remaining: 30.2s
# 107:	learn: 0.8205203	total: 8.43s	remaining: 30.1s
# 108:	learn: 0.8224168	total: 8.51s	remaining: 30.1s
# 109:	learn: 0.8243325	total: 8.57s	remaining: 29.9s
# 110:	learn: 0.8267602	total: 8.67s	remaining: 29.9s
# 111:	learn: 0.8280551	total: 8.73s	remaining: 29.8s
# 112:	learn: 0.8294881	total: 8.83s	remaining: 29.8s
# 113:	learn: 0.8310859	total: 8.92s	remaining: 29.7s
# 114:	learn: 0.8325232	total: 8.99s	remaining: 29.6s
# 115:	learn: 0.8336701	total: 9.05s	remaining: 29.5s
# 116:	learn: 0.8356884	total: 9.12s	remaining: 29.4s
# 117:	learn: 0.8370107	total: 9.18s	remaining: 29.3s
# 118:	learn: 0.8377899	total: 9.22s	remaining: 29.1s
# 119:	learn: 0.8392457	total: 9.34s	remaining: 29.1s
# 120:	learn: 0.8400062	total: 9.41s	remaining: 29s
# 121:	learn: 0.8412238	total: 9.49s	remaining: 28.9s
# 122:	learn: 0.8419650	total: 9.59s	remaining: 28.9s
# 123:	learn: 0.8433516	total: 9.68s	remaining: 28.9s
# 124:	learn: 0.8444899	total: 9.78s	remaining: 28.9s
# 125:	learn: 0.8459158	total: 9.88s	remaining: 28.9s
# 126:	learn: 0.8468002	total: 9.95s	remaining: 28.7s
# 127:	learn: 0.8477620	total: 10s	remaining: 28.7s
# 128:	learn: 0.8490356	total: 10.1s	remaining: 28.6s
# 129:	learn: 0.8497581	total: 10.2s	remaining: 28.5s
# 130:	learn: 0.8507303	total: 10.3s	remaining: 28.5s
# 131:	learn: 0.8513929	total: 10.3s	remaining: 28.4s
# 132:	learn: 0.8526212	total: 10.4s	remaining: 28.3s
# 133:	learn: 0.8534778	total: 10.5s	remaining: 28.3s
# 134:	learn: 0.8550099	total: 10.6s	remaining: 28.3s
# 135:	learn: 0.8557552	total: 10.7s	remaining: 28.2s
# 136:	learn: 0.8561588	total: 10.8s	remaining: 28.2s
# 137:	learn: 0.8568284	total: 10.9s	remaining: 28.1s
# 138:	learn: 0.8575899	total: 11s	remaining: 28s
# 139:	learn: 0.8587528	total: 11.1s	remaining: 28s
# 140:	learn: 0.8592263	total: 11.1s	remaining: 27.8s
# 141:	learn: 0.8599871	total: 11.2s	remaining: 27.7s
# 142:	learn: 0.8610592	total: 11.3s	remaining: 27.7s
# 143:	learn: 0.8613345	total: 11.4s	remaining: 27.6s
# 144:	learn: 0.8620044	total: 11.4s	remaining: 27.5s
# 145:	learn: 0.8625071	total: 11.5s	remaining: 27.4s
# 146:	learn: 0.8633497	total: 11.5s	remaining: 27.3s
# 147:	learn: 0.8637818	total: 11.6s	remaining: 27.1s
# 148:	learn: 0.8641448	total: 11.7s	remaining: 27s
# 149:	learn: 0.8649649	total: 11.7s	remaining: 26.9s
# 150:	learn: 0.8655373	total: 11.9s	remaining: 26.9s
# 151:	learn: 0.8664387	total: 12s	remaining: 26.9s
# 152:	learn: 0.8668275	total: 12.1s	remaining: 26.9s
# 153:	learn: 0.8676755	total: 12.2s	remaining: 26.9s
# 154:	learn: 0.8681754	total: 12.3s	remaining: 26.9s
# 155:	learn: 0.8685151	total: 12.4s	remaining: 26.9s
# 156:	learn: 0.8693026	total: 12.6s	remaining: 26.9s
# 157:	learn: 0.8696710	total: 12.6s	remaining: 26.9s
# 158:	learn: 0.8699515	total: 12.7s	remaining: 26.7s
# 159:	learn: 0.8701336	total: 12.8s	remaining: 26.7s
# 160:	learn: 0.8704608	total: 12.9s	remaining: 26.7s
# 161:	learn: 0.8709842	total: 13s	remaining: 26.6s
# 162:	learn: 0.8713460	total: 13.1s	remaining: 26.6s
# 163:	learn: 0.8716952	total: 13.2s	remaining: 26.6s
# 164:	learn: 0.8723671	total: 13.4s	remaining: 26.6s
# 165:	learn: 0.8729496	total: 13.5s	remaining: 26.7s
# 166:	learn: 0.8735766	total: 13.6s	remaining: 26.7s
# 167:	learn: 0.8740838	total: 13.7s	remaining: 26.7s
# 168:	learn: 0.8746198	total: 13.8s	remaining: 26.6s
# 169:	learn: 0.8748778	total: 13.9s	remaining: 26.5s
# 170:	learn: 0.8757175	total: 14s	remaining: 26.4s
# 171:	learn: 0.8760004	total: 14s	remaining: 26.3s
# 172:	learn: 0.8765987	total: 14.1s	remaining: 26.2s
# 173:	learn: 0.8775786	total: 14.2s	remaining: 26.1s
# 174:	learn: 0.8776556	total: 14.3s	remaining: 26.1s
# 175:	learn: 0.8777793	total: 14.4s	remaining: 25.9s
# 176:	learn: 0.8782492	total: 14.5s	remaining: 25.9s
# 177:	learn: 0.8785134	total: 14.5s	remaining: 25.8s
# 178:	learn: 0.8786956	total: 14.7s	remaining: 25.8s
# 179:	learn: 0.8792141	total: 14.8s	remaining: 25.8s
# 180:	learn: 0.8796665	total: 14.8s	remaining: 25.7s
# 181:	learn: 0.8797466	total: 14.9s	remaining: 25.6s
# 182:	learn: 0.8799125	total: 15s	remaining: 25.6s
# 183:	learn: 0.8803247	total: 15.2s	remaining: 25.5s
# 184:	learn: 0.8804922	total: 15.2s	remaining: 25.4s
# 185:	learn: 0.8809383	total: 15.3s	remaining: 25.4s
# 186:	learn: 0.8814366	total: 15.4s	remaining: 25.3s
# 187:	learn: 0.8820187	total: 15.5s	remaining: 25.3s
# 188:	learn: 0.8820241	total: 15.6s	remaining: 25.2s
# 189:	learn: 0.8828170	total: 15.6s	remaining: 25s
# 190:	learn: 0.8831952	total: 15.7s	remaining: 24.9s
# 191:	learn: 0.8835966	total: 15.8s	remaining: 24.8s
# 192:	learn: 0.8839004	total: 15.9s	remaining: 24.8s
# 193:	learn: 0.8841277	total: 16s	remaining: 24.7s
# 194:	learn: 0.8844454	total: 16.1s	remaining: 24.7s
# 195:	learn: 0.8845993	total: 16.2s	remaining: 24.6s
# 196:	learn: 0.8846447	total: 16.3s	remaining: 24.5s
# 197:	learn: 0.8855621	total: 16.3s	remaining: 24.4s
# 198:	learn: 0.8859856	total: 16.4s	remaining: 24.3s
# 199:	learn: 0.8861371	total: 16.4s	remaining: 24.2s
# 200:	learn: 0.8865862	total: 16.5s	remaining: 24.1s
# 201:	learn: 0.8868204	total: 16.6s	remaining: 24s
# 202:	learn: 0.8868924	total: 16.6s	remaining: 23.8s
# 203:	learn: 0.8874346	total: 16.7s	remaining: 23.8s
# 204:	learn: 0.8881165	total: 16.8s	remaining: 23.7s
# 205:	learn: 0.8884495	total: 16.9s	remaining: 23.7s
# 206:	learn: 0.8885930	total: 17.1s	remaining: 23.7s
# 207:	learn: 0.8887377	total: 17.2s	remaining: 23.6s
# 208:	learn: 0.8892045	total: 17.2s	remaining: 23.5s
# 209:	learn: 0.8897122	total: 17.3s	remaining: 23.5s
# 210:	learn: 0.8898314	total: 17.4s	remaining: 23.4s
# 211:	learn: 0.8899294	total: 17.4s	remaining: 23.2s
# 212:	learn: 0.8900891	total: 17.5s	remaining: 23.1s
# 213:	learn: 0.8903618	total: 17.6s	remaining: 23s
# 214:	learn: 0.8904769	total: 17.7s	remaining: 22.9s
# 215:	learn: 0.8905844	total: 17.7s	remaining: 22.8s
# 216:	learn: 0.8908841	total: 17.8s	remaining: 22.7s
# 217:	learn: 0.8909715	total: 17.8s	remaining: 22.6s
# 218:	learn: 0.8912964	total: 17.9s	remaining: 22.5s
# 219:	learn: 0.8916672	total: 18s	remaining: 22.5s
# 220:	learn: 0.8916905	total: 18.1s	remaining: 22.4s
# 221:	learn: 0.8922782	total: 18.2s	remaining: 22.3s
# 222:	learn: 0.8923856	total: 18.3s	remaining: 22.3s
# 223:	learn: 0.8925569	total: 18.4s	remaining: 22.2s
# 224:	learn: 0.8926222	total: 18.5s	remaining: 22.1s
# 225:	learn: 0.8927160	total: 18.5s	remaining: 22s
# 226:	learn: 0.8931312	total: 18.6s	remaining: 21.9s
# 227:	learn: 0.8932546	total: 18.7s	remaining: 21.8s
# 228:	learn: 0.8933216	total: 18.7s	remaining: 21.6s
# 229:	learn: 0.8933396	total: 18.7s	remaining: 21.5s
# 230:	learn: 0.8937117	total: 18.8s	remaining: 21.4s
# 231:	learn: 0.8938603	total: 18.9s	remaining: 21.3s
# 232:	learn: 0.8941494	total: 19s	remaining: 21.2s
# 233:	learn: 0.8942877	total: 19s	remaining: 21.2s
# 234:	learn: 0.8946591	total: 19.1s	remaining: 21.1s
# 235:	learn: 0.8949033	total: 19.2s	remaining: 21s
# 236:	learn: 0.8949845	total: 19.2s	remaining: 20.9s
# 237:	learn: 0.8952845	total: 19.3s	remaining: 20.7s
# 238:	learn: 0.8955468	total: 19.4s	remaining: 20.7s
# 239:	learn: 0.8957660	total: 19.4s	remaining: 20.6s
# 240:	learn: 0.8958444	total: 19.5s	remaining: 20.5s
# 241:	learn: 0.8959024	total: 19.6s	remaining: 20.4s
# 242:	learn: 0.8961236	total: 19.8s	remaining: 20.4s
# 243:	learn: 0.8964219	total: 19.9s	remaining: 20.4s
# 244:	learn: 0.8966137	total: 20s	remaining: 20.3s
# 245:	learn: 0.8972190	total: 20.1s	remaining: 20.2s
# 246:	learn: 0.8973739	total: 20.1s	remaining: 20.1s
# 247:	learn: 0.8980441	total: 20.2s	remaining: 20.1s
# 248:	learn: 0.8984192	total: 20.4s	remaining: 20s
# 249:	learn: 0.8986406	total: 20.5s	remaining: 20s
# 250:	learn: 0.8988290	total: 20.6s	remaining: 19.9s
# 251:	learn: 0.8988924	total: 20.6s	remaining: 19.8s
# 252:	learn: 0.8989320	total: 20.7s	remaining: 19.7s
# 253:	learn: 0.8990425	total: 20.7s	remaining: 19.6s
# 254:	learn: 0.8991169	total: 20.8s	remaining: 19.5s
# 255:	learn: 0.8996491	total: 21s	remaining: 19.5s
# 256:	learn: 0.8998241	total: 21s	remaining: 19.4s
# 257:	learn: 0.9001095	total: 21.1s	remaining: 19.3s
# 258:	learn: 0.9005266	total: 21.2s	remaining: 19.2s
# 259:	learn: 0.9010042	total: 21.3s	remaining: 19.1s
# 260:	learn: 0.9010751	total: 21.4s	remaining: 19.1s
# 261:	learn: 0.9012338	total: 21.4s	remaining: 19s
# 262:	learn: 0.9012869	total: 21.5s	remaining: 18.9s
# 263:	learn: 0.9014922	total: 21.5s	remaining: 18.8s
# 264:	learn: 0.9017427	total: 21.6s	remaining: 18.7s
# 265:	learn: 0.9018004	total: 21.7s	remaining: 18.6s
# 266:	learn: 0.9019412	total: 21.7s	remaining: 18.5s
# 267:	learn: 0.9025299	total: 21.8s	remaining: 18.4s
# 268:	learn: 0.9030555	total: 21.9s	remaining: 18.3s
# 269:	learn: 0.9031228	total: 22s	remaining: 18.2s
# 270:	learn: 0.9032022	total: 22s	remaining: 18.1s
# 271:	learn: 0.9033559	total: 22.1s	remaining: 18.1s
# 272:	learn: 0.9034053	total: 22.3s	remaining: 18s
# 273:	learn: 0.9035378	total: 22.4s	remaining: 18s
# 274:	learn: 0.9036406	total: 22.4s	remaining: 17.9s
# 275:	learn: 0.9037070	total: 22.5s	remaining: 17.7s
# 276:	learn: 0.9039033	total: 22.5s	remaining: 17.7s
# 277:	learn: 0.9042625	total: 22.6s	remaining: 17.6s
# 278:	learn: 0.9044026	total: 22.7s	remaining: 17.5s
# 279:	learn: 0.9046111	total: 22.7s	remaining: 17.4s
# 280:	learn: 0.9048719	total: 22.8s	remaining: 17.3s
# 281:	learn: 0.9056431	total: 22.9s	remaining: 17.2s
# 282:	learn: 0.9058873	total: 23s	remaining: 17.1s
# 283:	learn: 0.9060297	total: 23s	remaining: 17s
# 284:	learn: 0.9062652	total: 23.1s	remaining: 17s
# 285:	learn: 0.9065988	total: 23.2s	remaining: 16.9s
# 286:	learn: 0.9066985	total: 23.3s	remaining: 16.8s
# 287:	learn: 0.9068757	total: 23.4s	remaining: 16.7s
# 288:	learn: 0.9074021	total: 23.5s	remaining: 16.7s
# 289:	learn: 0.9074617	total: 23.5s	remaining: 16.6s
# 290:	learn: 0.9078524	total: 23.7s	remaining: 16.5s
# 291:	learn: 0.9079105	total: 23.7s	remaining: 16.4s
# 292:	learn: 0.9079496	total: 23.8s	remaining: 16.3s
# 293:	learn: 0.9079846	total: 23.9s	remaining: 16.3s
# 294:	learn: 0.9080024	total: 24s	remaining: 16.2s
# 295:	learn: 0.9085455	total: 24.1s	remaining: 16.1s
# 296:	learn: 0.9086685	total: 24.2s	remaining: 16.1s
# 297:	learn: 0.9088525	total: 24.3s	remaining: 16s
# 298:	learn: 0.9089023	total: 24.4s	remaining: 15.9s
# 299:	learn: 0.9089587	total: 24.5s	remaining: 15.8s
# 300:	learn: 0.9093046	total: 24.6s	remaining: 15.8s
# 301:	learn: 0.9096115	total: 24.7s	remaining: 15.7s
# 302:	learn: 0.9098360	total: 24.8s	remaining: 15.6s
# 303:	learn: 0.9099456	total: 24.8s	remaining: 15.5s
# 304:	learn: 0.9102908	total: 24.9s	remaining: 15.4s
# 305:	learn: 0.9107452	total: 25s	remaining: 15.4s
# 306:	learn: 0.9109776	total: 25.1s	remaining: 15.3s
# 307:	learn: 0.9112199	total: 25.2s	remaining: 15.2s
# 308:	learn: 0.9113929	total: 25.3s	remaining: 15.1s
# 309:	learn: 0.9114789	total: 25.3s	remaining: 15s
# 310:	learn: 0.9117198	total: 25.4s	remaining: 14.9s
# 311:	learn: 0.9118661	total: 25.5s	remaining: 14.9s
# 312:	learn: 0.9119116	total: 25.6s	remaining: 14.8s
# 313:	learn: 0.9120117	total: 25.7s	remaining: 14.8s
# 314:	learn: 0.9120610	total: 25.8s	remaining: 14.7s
# 315:	learn: 0.9122562	total: 25.9s	remaining: 14.6s
# 316:	learn: 0.9122956	total: 26.1s	remaining: 14.6s
# 317:	learn: 0.9123346	total: 26.2s	remaining: 14.5s
# 318:	learn: 0.9124236	total: 26.2s	remaining: 14.4s
# 319:	learn: 0.9124725	total: 26.3s	remaining: 14.3s
# 320:	learn: 0.9125113	total: 26.4s	remaining: 14.2s
# 321:	learn: 0.9129603	total: 26.5s	remaining: 14.2s
# 322:	learn: 0.9129938	total: 26.6s	remaining: 14.1s
# 323:	learn: 0.9134986	total: 26.7s	remaining: 14s
# 324:	learn: 0.9135368	total: 26.9s	remaining: 14s
# 325:	learn: 0.9135742	total: 27s	remaining: 13.9s
# 326:	learn: 0.9136384	total: 27.1s	remaining: 13.8s
# 327:	learn: 0.9138051	total: 27.2s	remaining: 13.8s
# 328:	learn: 0.9138438	total: 27.3s	remaining: 13.7s
# 329:	learn: 0.9139060	total: 27.4s	remaining: 13.6s
# 330:	learn: 0.9139147	total: 27.5s	remaining: 13.5s
# 331:	learn: 0.9144272	total: 27.6s	remaining: 13.5s
# 332:	learn: 0.9144919	total: 27.7s	remaining: 13.4s
# 333:	learn: 0.9145754	total: 27.8s	remaining: 13.3s
# 334:	learn: 0.9146800	total: 28s	remaining: 13.3s
# 335:	learn: 0.9148556	total: 28s	remaining: 13.2s
# 336:	learn: 0.9152591	total: 28.1s	remaining: 13.1s
# 337:	learn: 0.9155093	total: 28.2s	remaining: 13s
# 338:	learn: 0.9156310	total: 28.3s	remaining: 12.9s
# 339:	learn: 0.9157349	total: 28.4s	remaining: 12.9s
# 340:	learn: 0.9158259	total: 28.5s	remaining: 12.8s
# 341:	learn: 0.9158929	total: 28.6s	remaining: 12.7s
# 342:	learn: 0.9161822	total: 28.7s	remaining: 12.6s
# 343:	learn: 0.9162291	total: 28.7s	remaining: 12.5s
# 344:	learn: 0.9164592	total: 28.8s	remaining: 12.5s
# 345:	learn: 0.9165032	total: 29s	remaining: 12.4s
# 346:	learn: 0.9167969	total: 29.1s	remaining: 12.3s
# 347:	learn: 0.9168967	total: 29.2s	remaining: 12.2s
# 348:	learn: 0.9169120	total: 29.3s	remaining: 12.2s
# 349:	learn: 0.9170831	total: 29.4s	remaining: 12.1s
# 350:	learn: 0.9171335	total: 29.5s	remaining: 12s
# 351:	learn: 0.9171475	total: 29.6s	remaining: 11.9s
# 352:	learn: 0.9174163	total: 29.7s	remaining: 11.9s
# 353:	learn: 0.9174704	total: 29.8s	remaining: 11.8s
# 354:	learn: 0.9176436	total: 29.9s	remaining: 11.7s
# 355:	learn: 0.9176490	total: 30s	remaining: 11.6s
# 356:	learn: 0.9176880	total: 30.1s	remaining: 11.6s
# 357:	learn: 0.9178747	total: 30.3s	remaining: 11.5s
# 358:	learn: 0.9179212	total: 30.4s	remaining: 11.4s
# 359:	learn: 0.9180560	total: 30.5s	remaining: 11.3s
# 360:	learn: 0.9180957	total: 30.6s	remaining: 11.3s
# 361:	learn: 0.9182786	total: 30.7s	remaining: 11.2s
# 362:	learn: 0.9183738	total: 30.8s	remaining: 11.1s
# 363:	learn: 0.9184637	total: 30.9s	remaining: 11s
# 364:	learn: 0.9186547	total: 31s	remaining: 11s
# 365:	learn: 0.9189721	total: 31.2s	remaining: 10.9s
# 366:	learn: 0.9190267	total: 31.3s	remaining: 10.8s
# 367:	learn: 0.9192449	total: 31.4s	remaining: 10.8s
# 368:	learn: 0.9193160	total: 31.5s	remaining: 10.7s
# 369:	learn: 0.9195272	total: 31.6s	remaining: 10.6s
# 370:	learn: 0.9195946	total: 31.7s	remaining: 10.5s
# 371:	learn: 0.9196323	total: 31.8s	remaining: 10.4s
# 372:	learn: 0.9197011	total: 31.9s	remaining: 10.4s
# 373:	learn: 0.9197182	total: 32s	remaining: 10.3s
# 374:	learn: 0.9197762	total: 32.2s	remaining: 10.2s
# 375:	learn: 0.9197880	total: 32.3s	remaining: 10.1s
# 376:	learn: 0.9199288	total: 32.4s	remaining: 10s
# 377:	learn: 0.9199869	total: 32.5s	remaining: 9.97s
# 378:	learn: 0.9200929	total: 32.6s	remaining: 9.89s
# 379:	learn: 0.9201500	total: 32.7s	remaining: 9.81s
# 380:	learn: 0.9202050	total: 32.8s	remaining: 9.73s
# 381:	learn: 0.9205333	total: 32.9s	remaining: 9.65s
# 382:	learn: 0.9207654	total: 33s	remaining: 9.58s
# 383:	learn: 0.9207976	total: 33.2s	remaining: 9.5s
# 384:	learn: 0.9209923	total: 33.3s	remaining: 9.42s
# 385:	learn: 0.9210750	total: 33.4s	remaining: 9.33s
# 386:	learn: 0.9215483	total: 33.5s	remaining: 9.25s
# 387:	learn: 0.9215938	total: 33.6s	remaining: 9.17s
# 388:	learn: 0.9216286	total: 33.7s	remaining: 9.09s
# 389:	learn: 0.9216428	total: 33.8s	remaining: 9.02s
# 390:	learn: 0.9218891	total: 33.9s	remaining: 8.93s
# 391:	learn: 0.9219491	total: 34s	remaining: 8.84s
# 392:	learn: 0.9219827	total: 34.1s	remaining: 8.77s
# 393:	learn: 0.9221023	total: 34.2s	remaining: 8.68s
# 394:	learn: 0.9223167	total: 34.3s	remaining: 8.6s
# 395:	learn: 0.9224827	total: 34.4s	remaining: 8.51s
# 396:	learn: 0.9226786	total: 34.5s	remaining: 8.43s
# 397:	learn: 0.9228449	total: 34.6s	remaining: 8.34s
# 398:	learn: 0.9229661	total: 34.7s	remaining: 8.25s
# 399:	learn: 0.9230912	total: 34.8s	remaining: 8.17s
# 400:	learn: 0.9231238	total: 34.9s	remaining: 8.09s
# 401:	learn: 0.9231330	total: 35s	remaining: 8.01s
# 402:	learn: 0.9232291	total: 35.1s	remaining: 7.93s
# 403:	learn: 0.9233267	total: 35.2s	remaining: 7.84s
# 404:	learn: 0.9234980	total: 35.3s	remaining: 7.76s
# 405:	learn: 0.9236138	total: 35.5s	remaining: 7.68s
# 406:	learn: 0.9236741	total: 35.6s	remaining: 7.6s
# 407:	learn: 0.9236862	total: 35.7s	remaining: 7.52s
# 408:	learn: 0.9237511	total: 35.8s	remaining: 7.44s
# 409:	learn: 0.9237775	total: 35.9s	remaining: 7.36s
# 410:	learn: 0.9238749	total: 36s	remaining: 7.28s
# 411:	learn: 0.9238991	total: 36.2s	remaining: 7.2s
# 412:	learn: 0.9239466	total: 36.2s	remaining: 7.11s
# 413:	learn: 0.9239974	total: 36.3s	remaining: 7.02s
# 414:	learn: 0.9240290	total: 36.5s	remaining: 6.94s
# 415:	learn: 0.9241063	total: 36.6s	remaining: 6.86s
# 416:	learn: 0.9241735	total: 36.7s	remaining: 6.77s
# 417:	learn: 0.9242471	total: 36.8s	remaining: 6.69s
# 418:	learn: 0.9244394	total: 36.9s	remaining: 6.61s
# 419:	learn: 0.9245779	total: 37s	remaining: 6.52s
# 420:	learn: 0.9247215	total: 37.1s	remaining: 6.44s
# 421:	learn: 0.9250415	total: 37.2s	remaining: 6.36s
# 422:	learn: 0.9250461	total: 37.4s	remaining: 6.27s
# 423:	learn: 0.9252376	total: 37.5s	remaining: 6.18s
# 424:	learn: 0.9253452	total: 37.6s	remaining: 6.1s
# 425:	learn: 0.9253914	total: 37.7s	remaining: 6.01s
# 426:	learn: 0.9254223	total: 37.8s	remaining: 5.93s
# 427:	learn: 0.9255478	total: 37.9s	remaining: 5.85s
# 428:	learn: 0.9257085	total: 38s	remaining: 5.76s
# 429:	learn: 0.9258036	total: 38.1s	remaining: 5.68s
# 430:	learn: 0.9258201	total: 38.3s	remaining: 5.59s
# 431:	learn: 0.9259329	total: 38.4s	remaining: 5.51s
# 432:	learn: 0.9260228	total: 38.5s	remaining: 5.42s
# 433:	learn: 0.9261613	total: 38.6s	remaining: 5.34s
# 434:	learn: 0.9261953	total: 38.7s	remaining: 5.25s
# 435:	learn: 0.9262050	total: 38.8s	remaining: 5.17s
# 436:	learn: 0.9262521	total: 39s	remaining: 5.08s
# 437:	learn: 0.9262817	total: 39.1s	remaining: 5s
# 438:	learn: 0.9263463	total: 39.2s	remaining: 4.91s
# 439:	learn: 0.9263753	total: 39.3s	remaining: 4.82s
# 440:	learn: 0.9265479	total: 39.4s	remaining: 4.73s
# 441:	learn: 0.9266981	total: 39.5s	remaining: 4.64s
# 442:	learn: 0.9267444	total: 39.6s	remaining: 4.56s
# 443:	learn: 0.9267943	total: 39.7s	remaining: 4.47s
# 444:	learn: 0.9268131	total: 39.8s	remaining: 4.39s
# 445:	learn: 0.9268324	total: 40s	remaining: 4.3s
# 446:	learn: 0.9269178	total: 40.1s	remaining: 4.21s
# 447:	learn: 0.9270163	total: 40.2s	remaining: 4.13s
# 448:	learn: 0.9271885	total: 40.3s	remaining: 4.04s
# 449:	learn: 0.9272148	total: 40.4s	remaining: 3.95s
# 450:	learn: 0.9272492	total: 40.5s	remaining: 3.86s
# 451:	learn: 0.9273052	total: 40.6s	remaining: 3.77s
# 452:	learn: 0.9273932	total: 40.8s	remaining: 3.69s
# 453:	learn: 0.9274245	total: 40.9s	remaining: 3.6s
# 454:	learn: 0.9276217	total: 41s	remaining: 3.51s
# 455:	learn: 0.9276696	total: 41.1s	remaining: 3.42s
# 456:	learn: 0.9277196	total: 41.2s	remaining: 3.34s
# 457:	learn: 0.9277580	total: 41.3s	remaining: 3.25s
# 458:	learn: 0.9277972	total: 41.4s	remaining: 3.16s
# 459:	learn: 0.9278350	total: 41.5s	remaining: 3.07s
# 460:	learn: 0.9278602	total: 41.7s	remaining: 2.98s
# 461:	learn: 0.9278957	total: 41.8s	remaining: 2.89s
# 462:	learn: 0.9279343	total: 41.9s	remaining: 2.8s
# 463:	learn: 0.9280820	total: 42s	remaining: 2.71s
# 464:	learn: 0.9281076	total: 42.1s	remaining: 2.62s
# 465:	learn: 0.9283559	total: 42.2s	remaining: 2.53s
# 466:	learn: 0.9283773	total: 42.3s	remaining: 2.45s
# 467:	learn: 0.9284746	total: 42.4s	remaining: 2.36s
# 468:	learn: 0.9285520	total: 42.5s	remaining: 2.27s
# 469:	learn: 0.9285569	total: 42.6s	remaining: 2.18s
# 470:	learn: 0.9287425	total: 42.7s	remaining: 2.09s
# 471:	learn: 0.9287577	total: 42.9s	remaining: 2s
# 472:	learn: 0.9287785	total: 43s	remaining: 1.91s
# 473:	learn: 0.9287920	total: 43.1s	remaining: 1.82s
# 474:	learn: 0.9288230	total: 43.2s	remaining: 1.73s
# 475:	learn: 0.9288939	total: 43.3s	remaining: 1.64s
# 476:	learn: 0.9289293	total: 43.4s	remaining: 1.55s
# 477:	learn: 0.9289384	total: 43.6s	remaining: 1.46s
# 478:	learn: 0.9291596	total: 43.7s	remaining: 1.37s
# 479:	learn: 0.9292881	total: 43.8s	remaining: 1.28s
# 480:	learn: 0.9293585	total: 43.9s	remaining: 1.19s
# 481:	learn: 0.9293923	total: 44s	remaining: 1.1s
# 482:	learn: 0.9294130	total: 44.1s	remaining: 1s
# 483:	learn: 0.9294303	total: 44.2s	remaining: 914ms
# 484:	learn: 0.9294551	total: 44.3s	remaining: 823ms
# 485:	learn: 0.9295158	total: 44.5s	remaining: 732ms
# 486:	learn: 0.9296446	total: 44.5s	remaining: 640ms
# 487:	learn: 0.9296967	total: 44.6s	remaining: 549ms
# 488:	learn: 0.9299939	total: 44.8s	remaining: 458ms
# 489:	learn: 0.9300385	total: 44.9s	remaining: 366ms
# 490:	learn: 0.9301270	total: 45s	remaining: 275ms
# 491:	learn: 0.9301923	total: 45.1s	remaining: 183ms
# 492:	learn: 0.9302318	total: 45.2s	remaining: 91.7ms
# 493:	learn: 0.9302574	total: 45.3s	remaining: 0us

# %%
# получаем предсказания на тестовых данных
preds = model.predict(test_data)

# %%
# считаем скор
r2_score(y_test, preds)
# Out:
# 0.882478595648297
